# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
# %matplotlib inline

# %%
#df = pd.read_csv("../../output/data_analysis_part2.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
df = pd.read_csv("../../output/data_analysis_major_versions.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()
#df.dtypes
# Out:
#                  NC             NO      E_Module        E_Line      T_Module  \
# count     71.000000      71.000000     71.000000  7.100000e+01     71.000000
# mean    2636.549296   20099.056338  12848.070423  1.456126e+06  42158.197183
# std     4501.123459   37739.553069   9926.783872  2.168071e+06  15276.920996
# min      664.000000    3311.000000   5215.000000  3.802620e+05  18090.000000
# 25%     1411.500000    9001.000000   8913.000000  7.411975e+05  28494.000000
# 50%     1547.000000   11245.000000  10233.000000  8.600530e+05  42424.000000
# 75%     1689.500000   13251.500000  11777.500000  1.086821e+06  55868.000000
# max    27695.000000  236064.000000  59786.000000  1.329646e+07  66493.000000
#
#              T_Line
# count  7.100000e+01
# mean   1.693256e+07
# std    6.411476e+06
# min    6.988294e+06
# 25%    1.176184e+07
# 50%    1.668392e+07
# 75%    2.220692e+07
# max    2.785436e+07

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line   T_Module    T_Line
#  NC        1.000000  0.997290   0.933711  0.992643   0.278196  0.280828
#  NO        0.997290  1.000000   0.940326  0.991353   0.317146  0.319947
#  E_Module  0.933711  0.940326   1.000000  0.941347   0.450819  0.455599
#  E_Line    0.992643  0.991353   0.941347  1.000000   0.275073  0.280312
#  T_Module  0.278196  0.317146   0.450819  0.275073   1.000000  0.998717
#  T_Line    0.280828  0.319947   0.455599  0.280312   0.998717  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Line']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.75, random_state=0)

linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
#linear_regression.fit(X, Y)
LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None, normalize=False)

y_pred = linear_regression.predict(X_test)

coeff_df = pd.DataFrame(linear_regression.coef_, X.columns, columns=['Coefficient'])
coeff_df

# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
#            Coefficient
#  NC         939.392153
#  NO         -54.435510
#  T_Module     2.106444

# %%
data = {'Observed':y_test, 'Predicted':y_pred, 'Difference':abs(y_test - y_pred), 'Percent Error':abs(y_test - y_pred)/y_test}
#data = {'Observed':Y, 'Predicted':y_pred}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed     Predicted    Difference  Percent Error  Version
# 26    917908  7.981824e+05  1.197256e+05       0.130433        0
# 27    884124  8.353091e+05  4.881489e+04       0.055213        1
# 48   6939726  6.744293e+06  1.954329e+05       0.028161        2
# 22   1106263  1.027736e+06  7.852739e+04       0.070984        3
# 30   1023147  9.409452e+05  8.220179e+04       0.080342        4
# 51   1054074  8.653098e+05  1.887642e+05       0.179081        5
# 7     380262  4.864316e+05  1.061696e+05       0.279201        6
# 59    732239  8.667983e+05  1.345593e+05       0.183764        7
# 34    872212  8.131509e+05  5.906107e+04       0.067714        8
# 70    802240  8.943163e+05  9.207631e+04       0.114774        9
# 56   1142295  9.802891e+05  1.620059e+05       0.141825       10
# 28    910475  7.168672e+05  1.936078e+05       0.212645       11
# 31    817206  8.363844e+05  1.917839e+04       0.023468       12
# 42    678591  9.279316e+05  2.493406e+05       0.367439       13
# 33    782812  1.072221e+06  2.894090e+05       0.369704       14
# 55   1477692  7.772638e+05  7.004282e+05       0.474001       15
# 69   1047441  8.784948e+05  1.689462e+05       0.161294       16
# 62    690661  7.858245e+05  9.516347e+04       0.137786       17
# 43   1036431  1.044047e+06  7.616329e+03       0.007349       18
# 4     581403  6.603835e+05  7.898053e+04       0.135845       19
# 65  10076195  8.962977e+06  1.113218e+06       0.110480       20
# 50   1568681  9.177156e+05  6.509654e+05       0.414976       21
# 2     618119  5.564955e+05  6.162345e+04       0.099695       22
# 40    823257  8.711936e+05  4.793662e+04       0.058228       23
# 11    860053  1.133628e+06  2.735747e+05       0.318090       24
# 3     571144  6.373157e+05  6.617172e+04       0.115858       25
# 54    824224  8.850378e+05  6.081384e+04       0.073783       26
# 45    838755  9.706642e+05  1.319092e+05       0.157268       27
# 10    711070  6.746528e+05  3.641725e+04       0.051215       28
# 41    877620  7.533898e+05  1.242302e+05       0.141554       29
# 49    763456  8.657608e+05  1.023048e+05       0.134002       30
# 53    899680  9.955482e+05  9.586819e+04       0.106558       31
# 57    745221  7.854737e+05  4.025272e+04       0.054014       32
# 32    606862  8.882479e+05  2.813859e+05       0.463674       33
# 14   1262202  1.130052e+06  1.321497e+05       0.104698       34
# 68   1276030  1.033776e+06  2.422538e+05       0.189850       35
# 19   1576607  1.090153e+06  4.864541e+05       0.308545       36
# 29   6780975  7.529844e+06  7.488694e+05       0.110437       37
# 52    965017  8.969563e+05  6.806075e+04       0.070528       38
# 35    744138  8.705921e+05  1.264541e+05       0.169934       39
# 18   1266817  1.115070e+06  1.517472e+05       0.119786       40
# 0     573223  5.402908e+05  3.293219e+04       0.057451       41
# 15    943666  1.085191e+06  1.415254e+05       0.149974       42
# 5     587631  7.293976e+05  1.417666e+05       0.241251       43
# 16   1350502  1.328133e+06  2.236897e+04       0.016563       44
# 20   1244730  9.013983e+05  3.433317e+05       0.275828       45
# 66    786108  1.105900e+06  3.197925e+05       0.406805       46
# 8     453317  5.647127e+05  1.113957e+05       0.245735       47
# 13    838155  1.194811e+06  3.566561e+05       0.425525       48
# 25    828733  8.985827e+05  6.984968e+04       0.084285       49
# 37    705175  8.576358e+05  1.524608e+05       0.216203       50
# 17   1402112  1.380213e+06  2.189880e+04       0.015618       51
# 60    771579  7.969311e+05  2.535211e+04       0.032857       52
# 46   7013664  8.644808e+06  1.631144e+06       0.232567       53

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 169365.9727815643
# Mean Squared Error: 41954408748.43249
# Root Mean Squared Error: 204827.75385292026

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Line']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.75, random_state=0)

linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
#linear_regression.fit(X, Y)
LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None, normalize=False)

y_pred = linear_regression.predict(X_test)

coeff_df = pd.DataFrame(linear_regression.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
#  NC         939.392153
#  NO         -54.435510
#  T_Module     2.106444

# %%
data = {'Observed':y_test, 'Predicted':y_pred, 'Difference':abs(y_test - y_pred), 'Percent Error':abs(y_test - y_pred)/y_test}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed     Predicted    Difference  Percent Error  Version
# 26    917908  7.981824e+05  1.197256e+05       0.130433        0
# 27    884124  8.353091e+05  4.881489e+04       0.055213        1
# 48   6939726  6.744293e+06  1.954329e+05       0.028161        2
# 22   1106263  1.027736e+06  7.852739e+04       0.070984        3
# 30   1023147  9.409452e+05  8.220179e+04       0.080342        4
# 51   1054074  8.653098e+05  1.887642e+05       0.179081        5
# 7     380262  4.864316e+05  1.061696e+05       0.279201        6
# 59    732239  8.667983e+05  1.345593e+05       0.183764        7
# 34    872212  8.131509e+05  5.906107e+04       0.067714        8
# 70    802240  8.943163e+05  9.207631e+04       0.114774        9
# 56   1142295  9.802891e+05  1.620059e+05       0.141825       10
# 28    910475  7.168672e+05  1.936078e+05       0.212645       11
# 31    817206  8.363844e+05  1.917839e+04       0.023468       12
# 42    678591  9.279316e+05  2.493406e+05       0.367439       13
# 33    782812  1.072221e+06  2.894090e+05       0.369704       14
# 55   1477692  7.772638e+05  7.004282e+05       0.474001       15
# 69   1047441  8.784948e+05  1.689462e+05       0.161294       16
# 62    690661  7.858245e+05  9.516347e+04       0.137786       17
# 43   1036431  1.044047e+06  7.616329e+03       0.007349       18
# 4     581403  6.603835e+05  7.898053e+04       0.135845       19
# 65  10076195  8.962977e+06  1.113218e+06       0.110480       20
# 50   1568681  9.177156e+05  6.509654e+05       0.414976       21
# 2     618119  5.564955e+05  6.162345e+04       0.099695       22
# 40    823257  8.711936e+05  4.793662e+04       0.058228       23
# 11    860053  1.133628e+06  2.735747e+05       0.318090       24
# 3     571144  6.373157e+05  6.617172e+04       0.115858       25
# 54    824224  8.850378e+05  6.081384e+04       0.073783       26
# 45    838755  9.706642e+05  1.319092e+05       0.157268       27
# 10    711070  6.746528e+05  3.641725e+04       0.051215       28
# 41    877620  7.533898e+05  1.242302e+05       0.141554       29
# 49    763456  8.657608e+05  1.023048e+05       0.134002       30
# 53    899680  9.955482e+05  9.586819e+04       0.106558       31
# 57    745221  7.854737e+05  4.025272e+04       0.054014       32
# 32    606862  8.882479e+05  2.813859e+05       0.463674       33
# 14   1262202  1.130052e+06  1.321497e+05       0.104698       34
# 68   1276030  1.033776e+06  2.422538e+05       0.189850       35
# 19   1576607  1.090153e+06  4.864541e+05       0.308545       36
# 29   6780975  7.529844e+06  7.488694e+05       0.110437       37
# 52    965017  8.969563e+05  6.806075e+04       0.070528       38
# 35    744138  8.705921e+05  1.264541e+05       0.169934       39
# 18   1266817  1.115070e+06  1.517472e+05       0.119786       40
# 0     573223  5.402908e+05  3.293219e+04       0.057451       41
# 15    943666  1.085191e+06  1.415254e+05       0.149974       42
# 5     587631  7.293976e+05  1.417666e+05       0.241251       43
# 16   1350502  1.328133e+06  2.236897e+04       0.016563       44
# 20   1244730  9.013983e+05  3.433317e+05       0.275828       45
# 66    786108  1.105900e+06  3.197925e+05       0.406805       46
# 8     453317  5.647127e+05  1.113957e+05       0.245735       47
# 13    838155  1.194811e+06  3.566561e+05       0.425525       48
# 25    828733  8.985827e+05  6.984968e+04       0.084285       49
# 37    705175  8.576358e+05  1.524608e+05       0.216203       50
# 17   1402112  1.380213e+06  2.189880e+04       0.015618       51
# 60    771579  7.969311e+05  2.535211e+04       0.032857       52
# 46   7013664  8.644808e+06  1.631144e+06       0.232567       53

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 169365.9727815643
# Mean Squared Error: 41954408748.43249
# Root Mean Squared Error: 204827.75385292026

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
