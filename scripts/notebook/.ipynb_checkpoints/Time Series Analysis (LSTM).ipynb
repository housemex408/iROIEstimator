# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.tools.eval_measures import rmse
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("../../output/data_analysis_major_versions_with_dates.csv", usecols=[' E_Module', ' Release Date'])
df.head()
# Out:
#     E_Module  Release Date
# 0       5215    2005-08-28
# 1       5223    2005-10-27
# 2       6026    2006-01-02
# 3       6641    2006-03-19
# 4       6167    2006-06-17

# %%
# https://towardsdatascience.com/time-series-analysis-visualization-forecasting-with-lstm-77a905180eba
df[' Release Date'] = pd.to_datetime(df[' Release Date'])
# df['Year'] = df[' Release Date'].apply(lambda x: x.year)
# df['Quarter'] = df[' Release Date'].apply(lambda x: x.quarter)
# df['Month'] = df[' Release Date'].apply(lambda x: x.month)

df = df.set_index(" Release Date")

df.head()
# Out:
#                 E_Module
#  Release Date
# 2005-08-28          5215
# 2005-10-27          5223
# 2006-01-02          6026
# 2006-03-19          6641
# 2006-06-17          6167

# %%
# pd.pivot_table(df,index=["Year", "Quarter"],values=[" NC", " NO", " E_Module", " E_Line", " T_Module", " T_Line"], aggfunc=np.sum)
# pd.pivot_table(df,index=["Month"],values=[" NC", " NO", " E_Module", " E_Line", " T_Module", " T_Line"], aggfunc=np.sum)

# %%
train, test = df[:-12], df[-12:]

# %%
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit_generator(generator,epochs=90)
# Out:
# Epoch 1/90
# 9/9 [==============================] - 5s 509ms/step - loss: 0.0780
# Epoch 2/90
# 9/9 [==============================] - 1s 67ms/step - loss: 0.0277
# Epoch 3/90
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0327
# Epoch 4/90
# 9/9 [==============================] - 1s 117ms/step - loss: 0.0279
# Epoch 5/90
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0287
# Epoch 6/90
# 9/9 [==============================] - 1s 68ms/step - loss: 0.0276
# Epoch 7/90
# 9/9 [==============================] - 1s 67ms/step - loss: 0.0258
# Epoch 8/90
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0292
# Epoch 9/90
# 9/9 [==============================] - 1s 65ms/step - loss: 0.0248
# Epoch 10/90
# 9/9 [==============================] - 1s 72ms/step - loss: 0.0287
# Epoch 11/90
# 9/9 [==============================] - 1s 75ms/step - loss: 0.0273
# Epoch 12/90
# 9/9 [==============================] - 1s 96ms/step - loss: 0.0299
# ...

# %%
pred_list = []

batch = train[-n_input:].reshape((1, n_input, n_features))

for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index=df[-n_input:].index, columns=['Prediction'])

df_test = pd.concat([df,df_predict], axis=1)

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_test.index, df_test[' E_Module'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
pred_actual_rmse = rmse(df_test.iloc[-n_input:, [0]], df_test.iloc[-n_input:, [1]])
print("rmse: ", pred_actual_rmse)
# Out:
# rmse:  [27906.11811539]

# %%
train = df

# %%
scaler.fit(train)
train = scaler.transform(train)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model.fit_generator(generator,epochs=90)
# Out:
# Epoch 1/90
# 11/11 [==============================] - 1s 106ms/step - loss: 0.0198
# Epoch 2/90
# 11/11 [==============================] - 1s 110ms/step - loss: 0.0153
# Epoch 3/90
# 11/11 [==============================] - 1s 101ms/step - loss: 0.0150
# Epoch 4/90
# 11/11 [==============================] - 1s 76ms/step - loss: 0.0144
# Epoch 5/90
# 11/11 [==============================] - 1s 62ms/step - loss: 0.0155
# Epoch 6/90
# 11/11 [==============================] - 1s 60ms/step - loss: 0.0137
# Epoch 7/90
# 11/11 [==============================] - 1s 58ms/step - loss: 0.0137
# Epoch 8/90
# 11/11 [==============================] - 1s 64ms/step - loss: 0.0140
# Epoch 9/90
# 11/11 [==============================] - 1s 53ms/step - loss: 0.0143
# Epoch 10/90
# 11/11 [==============================] - 1s 51ms/step - loss: 0.0158
# Epoch 11/90
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0143
# Epoch 12/90
# ...

# %%
pred_list = []

batch = train[-n_input:].reshape((1, n_input, n_features))

for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
from pandas.tseries.offsets import DateOffset
add_dates = [df.index[-1] + DateOffset(months=x) for x in range(0,13) ]
future_dates = pd.DataFrame(index=add_dates[1:],columns=df.columns)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index=future_dates[-n_input:].index, columns=['Prediction'])

df_proj = pd.concat([df,df_predict], axis=1)

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_proj.index, df_proj[' E_Module'])
plt.plot(df_proj.index, df_proj['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
