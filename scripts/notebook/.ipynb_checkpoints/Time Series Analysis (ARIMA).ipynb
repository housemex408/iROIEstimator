# %%
import pandas as pd
from pandas import datetime
from pandas import DataFrame
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from pmdarima.arima import auto_arima
from plotly.offline import plot_mpl
from statsmodels.tsa.seasonal import seasonal_decompose
from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
variable = ' E_Module'

df = pd.read_csv("../../output/data_analysis_major_versions_with_dates.csv", usecols=[variable, ' Release Date'])
df[' Release Date'] = pd.to_datetime(df[' Release Date'])
df = df.set_index(' Release Date')
df.index = df.index.strftime('%Y-%m-%d') 
df.head()
# Out:
#                 E_Module
#  Release Date
# 2005-08-28          5215
# 2005-10-27          5223
# 2006-01-02          6026
# 2006-03-19          6641
# 2006-06-17          6167

# %%
train = df[0:55] # 55 observations in train data
test = df[55:] # 19 observations in test data

# %%
result = seasonal_decompose(train, model='additive', period=12)
fig = result.plot()
plot_mpl(fig)
# Out:
# 'temp-plot.html'

# %%
arima_model = auto_arima(train, m=12)
print(arima_model.aic())
# Out:
# 935.8424644436242

# %%
forecast = arima_model.predict(n_periods=len(test))
forecast = pd.DataFrame(forecast,index = test.index,columns=['Prediction'])

# %%
#plot the predictions for validation set
plt.plot(train, label='Train')
plt.plot(test, label='Valid')
plt.plot(forecast, label='Prediction')
plt.show()

# %%
#calculate rmse
mse = mean_squared_error(test,forecast)
print(mse)

rms = sqrt(mse)
print(rms)

mae = mean_absolute_error(test,forecast)
print(mae)
# Out:
# 27715266.423739344
# 5264.529079009759
# 2528.266483462116

# %%
simple_series = pd.Series(df[variable], df.index)


simple_smoothing_model = SimpleExpSmoothing(simple_series).fit()
simple_forecast = simple_smoothing_model.forecast(12).rename(r'$\alpha=%s$'%simple_smoothing_model.model.params['smoothing_level'])
# plot
simple_forecast.plot(marker='o', color='green', legend=True)
simple_smoothing_model.fittedvalues.plot(marker='o', color='green')

plt.show()
# Out:
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
holt_model = Holt(simple_series, damped=True).fit(smoothing_level=0.8, smoothing_slope=0.2)
holt_forecast = holt_model.forecast(12).rename("Additive damped trend")

holt_model.fittedvalues.plot(marker="o", color='green')
holt_forecast.plot(color='green', marker="o", legend=True)

plt.show()
# Out:
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
holt_winters_add = ExponentialSmoothing(simple_series, seasonal_periods=12, trend='add', seasonal='add').fit(use_boxcox=True)
holt_winters_mul = ExponentialSmoothing(simple_series, seasonal_periods=12, trend='add', seasonal='mul').fit(use_boxcox=True)

holt_winters_add.fittedvalues.plot(style='--', color='red')
holt_winters_mul.fittedvalues.plot(style='--', color='green')

holt_winters_add.forecast(12).plot(style='--', marker='o', color='red', legend=True)
holt_winters_mul.forecast(12).plot(style='--', marker='o', color='green', legend=True)

plt.show()
# Out:
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
from fbprophet import Prophet
import logging
logging.getLogger().setLevel(logging.ERROR)

# %%
simple_series = simple_series.reset_index()
simple_series.columns = ['ds', 'y']

# %%
prediction_size = 12
train_df = simple_series[:-prediction_size]

# %%
m = Prophet(seasonality_mode='multiplicative')
m.fit(train_df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=prediction_size, freq='M')
forecast = m.predict(future)

# %%
single_plot = m.plot(forecast)

# %%
plt.figure(figsize=(22, 10))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test', color='r')
plt.plot(forecast['ds'][69:], forecast['yhat'][69:], label='Prophet', color='k')
plt.legend(loc='best', fontsize='xx-large')
plt.show()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-83dab1ec81bf> in <module>
#       4 plt.plot(forecast['ds'][69:], forecast['yhat'][69:], label='Prophet', color='k')
#       5 plt.legend(loc='best', fontsize='xx-large')
# ----> 6 plt.show()
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1405         'Get the tick instances; grow as necessary.'
#    1406         if numticks is None:
# -> 1407             numticks = len(self.get_majorticklocs())
#    1408
#    1409         while len(self.majorTicks) < numticks:
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1426     def __call__(self):
#    1427         'Return the locations of the ticks'
# -> 1428         self.refresh()
#    1429         return self._locator()
#    1430
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1446     def refresh(self):
#    1447         'Refresh internal information based on current limits.'
# -> 1448         dmin, dmax = self.viewlim_to_dt()
#    1449         self._locator = self.get_locator(dmin, dmax)
#    1450
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1197                              'often happens if you pass a non-datetime '
#    1198                              'value to an axis that has datetime units'
# -> 1199                              .format(vmin))
#    1200         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1201
#
# ValueError: view limit minimum -36849.9 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
