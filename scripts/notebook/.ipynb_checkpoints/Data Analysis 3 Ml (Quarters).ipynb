# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
# %matplotlib inline

# %%
#df = pd.read_csv("../../output/data_analysis_rc.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
df = pd.read_csv("../../output/data_analysis_major_versions_by_quarters.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()

def calculate_PRED(percentage, dataFrame):
    countLessPercent = dataFrame[dataFrame['Percent Error'] < percentage]['Percent Error']
    # print(countLessPercent.count())
    # print(dataFrame['Percent Error'].count())
    pred = countLessPercent.count() / dataFrame['Percent Error'].count()
    return pred
#df.dtypes

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line   T_Module    T_Line
#  NC        1.000000  0.997268   0.064079 -0.027294   0.267723  0.271165
#  NO        0.997268  1.000000   0.084717 -0.033379   0.307195  0.310770
#  E_Module  0.064079  0.084717   1.000000  0.363999   0.607907  0.614143
#  E_Line   -0.027294 -0.033379   0.363999  1.000000   0.193617  0.210686
#  T_Module  0.267723  0.307195   0.607907  0.193617   1.000000  0.998708
#  T_Line    0.271165  0.310770   0.614143  0.210686   0.998708  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO']]
Y = df[' E_Line']
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.25, test_size=0.75, random_state=0)

linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
#linear_regression.fit(X, Y)
LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None, normalize=False)

y_pred = linear_regression.predict(X_test)

coeff_df = pd.DataFrame(linear_regression.coef_, X.columns, columns=['Coefficient'])
coeff_df

# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
#      Coefficient
#  NC     5.894344
#  NO    -1.593318

# %%
data = {'Observed':y_test, 'Predicted':y_pred.round(2), 'Difference':abs(y_test - y_pred).round(2), 'Percent Error':(abs(y_test - y_pred)/y_test).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed  Predicted  Difference  Percent Error  Version
# 50    816524  977097.31   160573.31           0.20        0
# 54    688469  966069.73   277600.73           0.40        1
# 22   1104325  971771.78   132553.22           0.12        2
# 43    743128  966474.65   223346.65           0.30        3
# 28    908516  970648.85    62132.85           0.07        4
# 26    915478  969315.24    53837.24           0.06        5
# 65   1140772  966321.42   174450.58           0.15        6
# 51    730440  965981.99   235541.99           0.32        7
# 34   1035204  968843.46    66360.54           0.06        8
# 7     377755  974340.02   596585.02           1.58        9
# 42    871130  964854.72    93724.72           0.11       10
# 56    987030  963885.60    23144.40           0.02       11
# 40    605282  967272.59   361990.59           0.60       12
# 61    962347  965290.28     2943.28           0.00       13
# 33    675960  970118.15   294158.15           0.44       14
# 66    744287  964030.38   219743.38           0.30       15
# 27    880569  970894.08    90325.08           0.10       16
# 48    634318  966348.65   332030.65           0.52       17
# 57    993822  873759.34   120062.66           0.12       18
# 53    766322  965387.15   199065.15           0.26       19
# 6     733880  973150.04   239270.04           0.33       20
# 49   1288335  977097.31   311237.69           0.24       21
# 69    785194  967596.14   182402.14           0.23       22
# 4     579964  974461.69   394497.69           0.68       23
# 55    907127  965423.97    58296.97           0.06       24
# 59   1567601  964366.89   603234.11           0.38       25
# 2     616945  974555.67   357610.67           0.58       26
# 73    801262  964373.79   163111.79           0.20       27
# 45    704439  968113.46   263674.46           0.37       28
# 11    858220  972976.06   114756.06           0.13       29
# 30    779975  969745.96   189770.96           0.24       30
# 3     570762  974820.39   404058.39           0.71       31
# 60   1052868  965833.35    87034.65           0.08       32
# 10    704767  973356.51   268589.51           0.38       33
# 31    818291  968961.42   150670.42           0.18       34
# 62    898671  964333.33    65662.33           0.07       35
# 52    770797  966615.93   195818.93           0.25       36
# 63    822847  965078.86   142231.86           0.17       37
# 32    876146  968137.63    91991.63           0.10       38
# 14   1260098  971668.54   288429.46           0.23       39
# 41    782125  968536.87   186411.87           0.24       40
# 19   1576515  970900.27   605614.73           0.38       41
# 29   1011563  977097.31    34465.69           0.03       42
# 71   1275301  965118.67   310182.33           0.24       43
# 35    823773  967156.25   143383.25           0.17       44
# 18   1265789  971131.12   294657.88           0.23       45
# 0     573223  975789.13   402566.13           0.70       46
# 72   1046164  963959.52    82204.48           0.08       47
# 15    943440  973324.13    29884.13           0.03       48
# 5     586438  974216.38   387778.38           0.66       49
# 16   1350113  971836.87   378276.13           0.28       50
# 20   1239188  969283.55   269904.45           0.22       51
# 68    807060  833977.15    26917.15           0.03       52
# 8     452257  974666.57   522409.57           1.16       53
# 13    837108  973245.11   136137.11           0.16       54
# 25    827270  970966.50   143696.50           0.17       55

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 60.71%
# PRED (50): 83.93%

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 218696.60231459094
# Mean Squared Error: 70174737099.86052
# Root Mean Squared Error: 264905.14736384514

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Line']
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.25, test_size=0.75, random_state=0)

linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
#linear_regression.fit(X, Y)
LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None, normalize=False)

y_pred = linear_regression.predict(X_test)

coeff_df = pd.DataFrame(linear_regression.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
#  NC          66.977156
#  NO          -9.452983
#  T_Module     5.608277

# %%
data = {'Observed':y_test, 'Predicted':y_pred.round(2), 'Difference':abs(y_test - y_pred).round(2), 'Percent Error':(abs(y_test - y_pred)/y_test).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed   Predicted  Difference  Percent Error  Version
# 50    816524  1027337.64   210813.64           0.26        0
# 54    688469  1023585.19   335116.19           0.49        1
# 22   1104325   943138.75   161186.25           0.15        2
# 43    743128   990627.40   247499.40           0.33        3
# 28    908516   945457.17    36941.17           0.04        4
# 26    915478   940956.63    25478.63           0.03        5
# 65   1140772  1069567.42    71204.58           0.06        6
# 51    730440  1014684.97   284244.97           0.39        7
# 34   1035204   972685.03    62518.97           0.06        8
# 7     377755   864693.14   486938.14           1.29        9
# 42    871130   977367.21   106237.21           0.12       10
# 56    987030  1037710.44    50680.44           0.05       11
# 40    605282   981384.30   376102.30           0.62       12
# 61    962347  1062946.95   100599.95           0.10       13
# 33    675960   966857.33   290897.33           0.43       14
# 66    744287  1054953.50   310666.50           0.42       15
# 27    880569   950013.79    69444.79           0.08       16
# 48    634318   994637.65   360319.65           0.57       17
# 57    993822   886562.37   107259.63           0.11       18
# 53    766322  1020858.54   254536.54           0.33       19
# 6     733880   864313.65   130433.65           0.18       20
# 49   1288335  1022991.23   265343.77           0.21       21
# 69    785194  1096522.62   311328.62           0.40       22
# 4     579964   863251.06   283287.06           0.49       23
# 55    907127  1031188.95   124061.95           0.14       24
# 59   1567601  1051765.07   515835.93           0.33       25
# 2     616945   855070.34   238125.34           0.39       26
# 73    801262  1087457.49   286195.49           0.36       27
# 45    704439  1000411.06   295972.06           0.42       28
# 11    858220   896521.11    38301.11           0.04       29
# 30    779975   955133.84   175158.84           0.22       30
# 3     570762   862181.18   291419.18           0.51       31
# 60   1052868  1060085.80     7217.80           0.01       32
# 10    704767   875374.39   170607.39           0.24       33
# 31    818291   952809.58   134518.58           0.16       34
# 62    898671  1068551.82   169880.82           0.19       35
# 52    770797  1018310.98   247513.98           0.32       36
# 63    822847  1070453.98   247606.98           0.30       37
# 32    876146   946957.70    70811.70           0.08       38
# 14   1260098   897668.34   362429.66           0.29       39
# 41    782125  1000314.39   218189.39           0.28       40
# 19   1576515   926348.03   650166.97           0.41       41
# 29   1011563   949090.96    62472.04           0.06       42
# 71   1275301  1090024.48   185276.52           0.15       43
# 35    823773   961963.27   138190.27           0.17       44
# 18   1265789   920870.41   344918.59           0.27       45
# 0     573223   855880.24   282657.24           0.49       46
# 72   1046164  1080557.96    34393.96           0.03       47
# 15    943440   908062.89    35377.11           0.04       48
# 5     586438   868765.79   282327.79           0.48       49
# 16   1350113   919774.30   430338.70           0.32       50
# 20   1239188   916923.87   322264.13           0.26       51
# 68    807060   838437.12    31377.12           0.04       52
# 8     452257   871384.27   419127.27           0.93       53
# 13    837108   907036.59    69928.59           0.08       54
# 25    827270   948021.21   120751.21           0.15       55

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 50.00%
# PRED (50): 91.07%

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 213258.80578713692
# Mean Squared Error: 65154094756.035255
# Root Mean Squared Error: 255253.00146332316

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
