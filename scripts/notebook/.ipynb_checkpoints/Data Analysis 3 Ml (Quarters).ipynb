# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
# %matplotlib inline

# %%
#df = pd.read_csv("../../output/data_analysis_rc.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
df = pd.read_csv("../../output/data_analysis_major_versions_by_quarters.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()

def calculate_PRED(percentage, dataFrame):
    countLessPercent = dataFrame[dataFrame['Percent Error'] < percentage]['Percent Error']
    # print(countLessPercent.count())
    # print(dataFrame['Percent Error'].count())
    pred = countLessPercent.count() / dataFrame['Percent Error'].count()
    return pred
#df.dtypes

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line   T_Module    T_Line
#  NC        1.000000  0.997041   0.327255  0.227731   0.471144  0.473614
#  NO        0.997041  1.000000   0.326558  0.211488   0.484945  0.488758
#  E_Module  0.327255  0.326558   1.000000  0.800724   0.867390  0.867920
#  E_Line    0.227731  0.211488   0.800724  1.000000   0.712165  0.710523
#  T_Module  0.471144  0.484945   0.867390  0.712165   1.000000  0.999245
#  T_Line    0.473614  0.488758   0.867920  0.710523   0.999245  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO']]
Y = df[' E_Line']
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.876, test_size=0.124, random_state=0)

linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
#linear_regression.fit(X, Y)
LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None, normalize=False)

y_pred = linear_regression.predict(X_test)

coeff_df = pd.DataFrame(linear_regression.coef_, X.columns, columns=['Coefficient'])
coeff_df

# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
#      Coefficient
#  NC   260.375989
#  NO   -28.101414

# %%
data = {'Observed':y_test, 'Predicted':y_pred.round(2), 'Difference':abs(y_test - y_pred).round(2), 'Percent Error':(abs(y_test - y_pred)/y_test).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed   Predicted  Difference  Percent Error  Version
# 26   1791538  1069911.78   721626.22           0.40        0
# 35    871130   995532.52   124402.52           0.14        1
# 43    766322  1013682.45   247360.45           0.32        2
# 28   1552106  1128522.29   423583.71           0.27        3
# 11   1065087  1187063.31   121976.31           0.11        4
# 2    1187707  1159005.23    28701.77           0.02        5
# 34   1387407  1156858.95   230548.05           0.17        6
# 46    993822  1300924.27   307102.27           0.31        7

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 50.00%
# PRED (50): 100.00%

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared', linear_regression.score())
# Out:
# Mean Absolute Error: 275662.6634713189
# Mean Squared Error: 117499620004.68758
# Root Mean Squared Error: 342782.1757394739
# R Squared -0.08534314068931348

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Line']
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.876, test_size=0.124, random_state=0)

linear_regression = LinearRegression()
linear_regression.fit(X_train, y_train)
#linear_regression.fit(X, Y)
LinearRegression(fit_intercept=True, copy_X=True, n_jobs=None, normalize=False)

y_pred = linear_regression.predict(X_test)

coeff_df = pd.DataFrame(linear_regression.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#            Coefficient
#  NC         465.349178
#  NO         -58.064185
#  T_Module    15.214179

# %%
data = {'Observed':y_test, 'Predicted':y_pred.round(2), 'Difference':abs(y_test - y_pred).round(2), 'Percent Error':(abs(y_test - y_pred)/y_test).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed   Predicted  Difference  Percent Error  Version
# 26   1791538  1497826.72   293711.28           0.16        0
# 35    871130   898732.61    27602.61           0.03        1
# 43    766322  1036718.16   270396.16           0.35        2
# 28   1552106  1568982.22    16876.22           0.01        3
# 11   1065087   911325.23   153761.77           0.14        4
# 2    1187707  1088635.99    99071.01           0.08        5
# 34   1387407  1778179.87   390772.87           0.28        6
# 46    993822   800119.21   193702.79           0.19        7

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 75.00%
# PRED (50): 100.00%

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared', linear_regression.score(X_test, y_test))
# Out:
# Mean Absolute Error: 180736.83818930748
# Mean Squared Error: 48013632958.84366
# Root Mean Squared Error: 219120.1336227314
# R Squared 0.5564984194044511

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
