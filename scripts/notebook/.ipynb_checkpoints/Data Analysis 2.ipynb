# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
df = pd.read_csv("../../output/data_analysis_major_versions.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
#df = pd.read_csv("../../output/data_analysis_major_versions_by_quarters.csv")
df["E_Line"] = df["E_Line"].astype(str).astype(int)
df["E_Module"] = df["E_Module"].astype(str).astype(int)
# df[" NC"] = df[" NC"]
# df[" NO"] = df[" NO"]

# %%
df.describe()

def calculate_PRED(percentage, dataFrame):
    countLessPercent = dataFrame[dataFrame['Percent Error'] < percentage]['Percent Error']
    # print(countLessPercent.count())
    # print(dataFrame['Percent Error'].count())
    pred = countLessPercent.count() / dataFrame['Percent Error'].count()
    return pred
#df.dtypes

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                 NT        NO  E_Module    E_Line  T_Module    T_Line
# NT        1.000000  0.997290  0.933711  0.992643  0.278196  0.280828
# NO        0.997290  1.000000  0.940326  0.991353  0.317146  0.319947
# E_Module  0.933711  0.940326  1.000000  0.941347  0.450819  0.455599
# E_Line    0.992643  0.991353  0.941347  1.000000  0.275073  0.280312
# T_Module  0.278196  0.317146  0.450819  0.275073  1.000000  0.998717
# T_Line    0.280828  0.319947  0.455599  0.280312  0.998717  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x='NT', y='E_Line', c='red')
df.plot.scatter(x='NO', y='E_Line', c='green')
df.plot.scatter(x='T_Module', y='E_Line', c='orange')
df.plot.scatter(x='T_Line', y='E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[['NT', 'NO']]
Y = df['E_Line']
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.876, test_size=0.124, random_state=0)
model = lm.OLS(y_train, X_train).fit()
predictions = model.predict(X_test)
 
print_model = model.summary()
print(print_model)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# OLS Regression Results
# =======================================================================================
# Dep. Variable:                 E_Line   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.985
# Method:                 Least Squares   F-statistic:                              1998.
# Date:                Tue, 26 May 2020   Prob (F-statistic):                    1.26e-55
# Time:                        17:29:38   Log-Likelihood:                         -873.58
# No. Observations:                  62   AIC:                                      1751.
# Df Residuals:                      60   BIC:                                      1755.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NT           612.0541     99.847      6.130      0.000     412.331     811.777
# NO           -14.3236     12.211     -1.173      0.245     -38.748      10.101
# ==============================================================================
# Omnibus:                       27.433   Durbin-Watson:                   1.495
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.673
# Skew:                          -0.896   Prob(JB):                     1.16e-33
# Kurtosis:                      10.450   Cond. No.                         106.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':y_test, 'Predicted':predictions.round(2), 'Difference':abs(y_test - predictions).round(2), 'Percent Error':(abs(y_test - predictions)/y_test).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed   Predicted  Difference  Percent Error  Version
# 26    917908   683660.63   234247.37           0.26        0
# 27    884124   684995.58   199128.42           0.23        1
# 48   6939726  6769340.37   170385.63           0.02        2
# 22   1106263   821470.94   284792.06           0.26        3
# 30   1023147   779938.71   243208.29           0.24        4
# 51   1054074   755227.15   298846.85           0.28        5
# 7     380262   387243.57     6981.57           0.02        6
# 59    732239   767185.62    34946.62           0.05        7
# 34    872212   754256.39   117955.61           0.14        8

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 66.67%
# PRED (50): 100.00%

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, "NT", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, "NO", fig=regPlotNO)

# %%
df.plot.scatter(x='NT', y='E_Line', c='red')
df.plot.scatter(x='NO', y='E_Line', c='green')
df.plot.scatter(x='T_Module', y='E_Line', c='orange')
df.plot.scatter(x='T_Line', y='E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[['NT', 'NO', 'T_Module']]
Y = df['E_Module']
X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.876, test_size=0.124, random_state=0)
model = lm.OLS(y_train, X_train).fit()
predictions = model.predict(X_test)
 
print_model = model.summary()
print(print_model)
# Out:
# OLS Regression Results
# =======================================================================================
# Dep. Variable:               E_Module   R-squared (uncentered):                   0.963
# Model:                            OLS   Adj. R-squared (uncentered):              0.961
# Method:                 Least Squares   F-statistic:                              506.9
# Date:                Tue, 26 May 2020   Prob (F-statistic):                    4.65e-42
# Time:                        17:29:45   Log-Likelihood:                         -587.38
# No. Observations:                  62   AIC:                                      1181.
# Df Residuals:                      59   BIC:                                      1187.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NT             2.8844      1.053      2.738      0.008       0.776       4.992
# NO            -0.1189      0.127     -0.937      0.352      -0.373       0.135
# T_Module       0.1796      0.011     15.773      0.000       0.157       0.202
# ==============================================================================
# Omnibus:                       58.288   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              334.739
# Skew:                           2.653   Prob(JB):                     2.05e-73
# Kurtosis:                      13.071   Cond. No.                         141.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':y_test, 'Predicted':predictions.round(2), 'Difference':abs(y_test - predictions).round(2), 'Percent Error':(abs(y_test - predictions)/y_test).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed  Predicted  Difference  Percent Error  Version
# 26     10645    9305.17     1339.83           0.13        0
# 27      7949    9380.46     1431.46           0.18        1
# 48     37904   36215.73     1688.27           0.04        2
# 22      8869    9385.66      516.66           0.06        3
# 30      9641   11037.02     1396.02           0.14        4
# 51     10795   13782.00     2987.00           0.28        5
# 7       5868    5416.70      451.30           0.08        6
# 59     10076   12338.24     2262.24           0.22        7
# 34     10812   11266.31      454.31           0.04        8

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 88.89%
# PRED (50): 100.00%

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, "NT", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, "NO", fig=regPlotNO)
