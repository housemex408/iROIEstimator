# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
# %matplotlib inline

# %%
df = pd.read_csv("../../output/data_analysis_major_versions.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
#df = pd.read_csv("../../output/data_analysis_rc.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()
#df.dtypes
# Out:
#                  NC             NO      E_Module        E_Line      T_Module  \
# count     71.000000      71.000000     71.000000  7.100000e+01     71.000000
# mean    2636.549296   20099.056338  12848.070423  1.456126e+06  42158.197183
# std     4501.123459   37739.553069   9926.783872  2.168071e+06  15276.920996
# min      664.000000    3311.000000   5215.000000  3.802620e+05  18090.000000
# 25%     1411.500000    9001.000000   8913.000000  7.411975e+05  28494.000000
# 50%     1547.000000   11245.000000  10233.000000  8.600530e+05  42424.000000
# 75%     1689.500000   13251.500000  11777.500000  1.086821e+06  55868.000000
# max    27695.000000  236064.000000  59786.000000  1.329646e+07  66493.000000
#
#              T_Line
# count  7.100000e+01
# mean   1.693256e+07
# std    6.411476e+06
# min    6.988294e+06
# 25%    1.176184e+07
# 50%    1.668392e+07
# 75%    2.220692e+07
# max    2.785436e+07

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line   T_Module    T_Line
#  NC        1.000000  0.997290   0.933711  0.992643   0.278196  0.280828
#  NO        0.997290  1.000000   0.940326  0.991353   0.317146  0.319947
#  E_Module  0.933711  0.940326   1.000000  0.941347   0.450819  0.455599
#  E_Line    0.992643  0.991353   0.941347  1.000000   0.275073  0.280312
#  T_Module  0.278196  0.317146   0.450819  0.275073   1.000000  0.998717
#  T_Line    0.280828  0.319947   0.455599  0.280312   0.998717  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Line']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:                 E_Line   R-squared:                       0.989
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     2088.
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):           7.43e-67
# Time:                        00:45:23   Log-Likelihood:                -988.50
# No. Observations:                  71   AIC:                             1983.
# Df Residuals:                      68   BIC:                             1990.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC          499.4443     88.020      5.674      0.000     323.804     675.085
#  NO           -2.6751     10.575     -0.253      0.801     -23.776      18.426
#  T_Module      4.0775      0.919      4.439      0.000       2.244       5.911
# ==============================================================================
# Omnibus:                       14.282   Durbin-Watson:                   1.619
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               59.195
# Skew:                          -0.046   Prob(JB):                     1.40e-13
# Kurtosis:                       7.472   Cond. No.                         148.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed     Predicted  Version
# 0     573223  4.397049e+05        0
# 1     495661  3.979376e+05        1
# 2     618119  4.782690e+05        2
# 3     571144  5.275042e+05        3
# 4     581403  5.511421e+05        4
# 5     587631  6.038244e+05        5
# 6     738257  5.712237e+05        6
# 7     380262  4.429358e+05        7
# 8     453317  4.889052e+05        8
# 9     693510  5.512676e+05        9
# 10    711070  5.917771e+05       10
# 11    860053  9.056392e+05       11
# 12   1067379  1.070895e+06       12
# 13    838155  9.438162e+05       13
# 14   1262202  9.341645e+05       14
# 15    943666  8.720812e+05       15
# 16   1350502  1.068228e+06       16
# 17   1402112  1.115941e+06       17
# 18   1266817  9.482527e+05       18
# 19   1576607  9.402538e+05       19
# 20   1244730  8.518662e+05       20
# 21    813192  8.169905e+05       21
# 22   1106263  8.881504e+05       22
# 23   1135701  8.687536e+05       23
# 24   1521851  1.019504e+06       24
# 25    828733  8.262114e+05       25
# 26    917908  7.965162e+05       26
# 27    884124  7.882172e+05       27
# 28    910475  7.156088e+05       28
# 29   6780975  6.749059e+06       29
# ..       ...           ...      ...
# 41    877620  7.979200e+05       41
# 42    678591  8.738479e+05       42
# 43   1036431  9.807603e+05       43
# 44    824362  9.167940e+05       44
# 45    838755  9.464708e+05       45
# 46   7013664  8.108875e+06       46
# 47    634858  8.400961e+05       47
# 48   6939726  6.800817e+06       48
# 49    763456  9.633011e+05       49
# 50   1568681  1.041655e+06       50
# 51   1054074  9.780963e+05       51
# 52    965017  1.012382e+06       52
# 53    899680  1.100576e+06       53
# 54    824224  1.013267e+06       54
# 55   1477692  9.528453e+05       55
# 56   1142295  1.045253e+06       56
# 57    745221  9.660591e+05       57
# 58  13296464  1.345538e+07       58
# 59    732239  9.535557e+05       59
# 60    771579  8.957708e+05       60
# 61    768686  9.833914e+05       61
# 62    690661  9.038420e+05       62
# 63    910106  9.875411e+05       63
# 64    987956  1.164662e+06       64
# 65  10076195  9.123223e+06       65
# 66    786108  1.109519e+06       66
# 67   1050273  1.009758e+06       67
# 68   1276030  1.117383e+06       68
# 69   1047441  1.039882e+06       69
# 70    802240  1.043807e+06       70
#
# [71 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Module']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:               E_Module   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     639.9
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):           9.49e-50
# Time:                        00:45:31   Log-Likelihood:                -669.08
# No. Observations:                  71   AIC:                             1344.
# Df Residuals:                      68   BIC:                             1351.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC            2.8985      0.979      2.961      0.004       0.945       4.852
#  NO           -0.1178      0.118     -1.002      0.320      -0.352       0.117
#  T_Module      0.1760      0.010     17.224      0.000       0.156       0.196
# ==============================================================================
# Omnibus:                       67.344   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              487.579
# Skew:                           2.771   Prob(JB):                    1.33e-106
# Kurtosis:                      14.580   Cond. No.                         148.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed     Predicted  Version
# 0       5215   4938.770290        0
# 1       5233   4778.638778        1
# 2       6036   5164.084236        2
# 3       6653   5497.508823        3
# 4       6197   5639.881643        4
# 5       8957   5990.671741        5
# 6       8021   5870.019290        6
# 7       5868   5356.074638        7
# 8       6463   5660.640014        8
# 9       7563   5998.003478        9
# 10      7160   6234.758240       10
# 11      9362   7871.455852       11
# 12      9568   8730.071735       12
# 13      8518   8268.937537       13
# 14     12282   8130.036680       14
# 15      9503   8066.228742       15
# 16     10112   9175.234793       16
# 17      9911   9572.572336       17
# 18      8836   8905.291001       18
# 19     10233   9063.707348       19
# 20      9632   8681.096827       20
# 21     10988   8746.683508       21
# 22      8869   9298.814210       22
# 23      9155   9357.711805       23
# 24     10909  10207.160704       24
# 25      8706   9330.940176       25
# 26     10645   9204.166083       26
# 27      7949   9277.633239       27
# 28      8847   8943.419514       28
# 29     35494  35541.134538       29
# ..       ...           ...      ...
# 41      9443   9505.682842       41
# 42      8266  10116.384043       42
# 43     13561  10752.945113       43
# 44     11285  10416.277390       44
# 45     10983  10784.248534       45
# 46     35998  41419.059850       46
# 47      9965  11211.376522       47
# 48     37904  36337.515108       48
# 49     12531  13150.142282       49
# 50     12435  13710.584864       50
# 51     10795  13601.469547       51
# 52     23240  13848.451648       52
# 53     13239  14386.941639       53
# 54     12087  14091.703205       54
# 55     14304  13498.764618       55
# 56     12996  14036.721447       56
# 57     11637  13601.940778       57
# 58     59786  63460.354223       58
# 59     10076  12187.852515       59
# 60     10648  12046.732273       60
# 61     10144  12522.710433       61
# 62      9844  12282.284071       62
# 63     11441  12832.530939       63
# 64     11211  13736.291854       64
# 65     55000  46337.563249       65
# 66     11893  14889.700986       66
# 67     30602  14294.003009       67
# 68     13254  14982.805391       68
# 69     12481  14585.427427       69
# 70     11662  14755.435668       70
#
# [71 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)
