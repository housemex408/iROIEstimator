# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
# %matplotlib inline

# %%
df = pd.read_csv("../../output/data_analysis_major_versions.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
#df = pd.read_csv("../../output/data_analysis_rc.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()

def calculate_PRED(percentage, dataFrame):
    countLessPercent = dataFrame[dataFrame['Percent Error'] < percentage]['Percent Error']
    # print(countLessPercent.count())
    # print(dataFrame['Percent Error'].count())
    pred = countLessPercent.count() / dataFrame['Percent Error'].count()
    return pred
#df.dtypes

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line   T_Module    T_Line
#  NC        1.000000  0.997290   0.933711  0.992643   0.278196  0.280828
#  NO        0.997290  1.000000   0.940326  0.991353   0.317146  0.319947
#  E_Module  0.933711  0.940326   1.000000  0.941347   0.450819  0.455599
#  E_Line    0.992643  0.991353   0.941347  1.000000   0.275073  0.280312
#  T_Module  0.278196  0.317146   0.450819  0.275073   1.000000  0.998717
#  T_Line    0.280828  0.319947   0.455599  0.280312   0.998717  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO']]
Y = df[' E_Line']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:                 E_Line   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                     2457.
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):           7.55e-65
# Time:                        20:50:13   Log-Likelihood:                -997.53
# No. Observations:                  71   AIC:                             1999.
# Df Residuals:                      69   BIC:                             2004.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC          630.2636     93.504      6.740      0.000     443.728     816.799
#  NO          -16.2756     11.410     -1.426      0.158     -39.039       6.487
# ==============================================================================
# Omnibus:                       36.286   Durbin-Watson:                   1.450
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              251.978
# Skew:                          -1.138   Prob(JB):                     1.92e-55
# Kurtosis:                      11.944   Cond. No.                         110.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions.round(2), 'Difference':abs(Y - predictions).round(2), 'Percent Error':(abs(Y - predictions)/Y).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed    Predicted  Difference  Percent Error  Version
# 0     573223    415317.12   157905.88           0.28        0
# 1     495661    364606.41   131054.59           0.26        1
# 2     618119    446611.52   171507.48           0.28        2
# 3     571144    504040.73    67103.27           0.12        3
# 4     581403    527169.14    54233.86           0.09        4
# 5     587631    583378.83     4252.17           0.01        5
# 6     738257    533152.53   205104.47           0.28        6
# 7     380262    391963.78    11701.78           0.03        7
# 8     453317    446604.22     6712.78           0.01        8
# 9     693510    502792.11   190717.89           0.28        9
# 10    711070    551223.08   159846.92           0.22       10
# 11    860053    911030.88    50977.88           0.06       11
# 12   1067379   1088685.73    21306.73           0.02       12
# 13    838155    951972.77   113817.77           0.14       13
# 14   1262202    927317.38   334884.62           0.27       14
# 15    943666    864421.63    79244.37           0.08       15
# 16   1350502   1073830.45   276671.55           0.20       16
# 17   1402112   1119735.37   282376.63           0.20       17
# 18   1266817    916697.21   350119.79           0.28       18
# 19   1576607    898947.69   677659.31           0.43       19
# 20   1244730    777543.13   467186.87           0.38       20
# 21    813192    749502.71    63689.29           0.08       21
# 22   1106263    832033.02   274229.98           0.25       22
# 23   1135701    805263.35   330437.65           0.29       23
# 24   1521851    970615.37   551235.63           0.36       24
# 25    828733    741149.34    87583.66           0.11       25
# 26    917908    688938.56   228969.44           0.25       26
# 27    884124    691955.08   192168.92           0.22       27
# 28    910475    603942.07   306532.93           0.34       28
# 29   6780975   7011643.94   230668.94           0.03       29
# ..       ...          ...         ...            ...      ...
# 41    877620    669498.68   208121.32           0.24       41
# 42    678591    771247.17    92656.17           0.14       42
# 43   1036431    879647.61   156783.39           0.15       43
# 44    824362    788306.03    36055.97           0.04       44
# 45    838755    828449.78    10305.22           0.01       45
# 46   7013664   8329006.53  1315342.53           0.19       46
# 47    634858    654644.66    19786.66           0.03       47
# 48   6939726   6794044.09   145681.91           0.02       48
# 49    763456    756531.92     6924.08           0.01       49
# 50   1568681    823658.81   745022.19           0.47       50
# 51   1054074    758261.11   295812.89           0.28       51
# 52    965017    790337.26   174679.74           0.18       52
# 53    899680    880321.40    19358.60           0.02       53
# 54    824224    781907.00    42317.00           0.05       54
# 55   1477692    712927.10   764764.90           0.52       55
# 56   1142295    838493.73   303801.27           0.27       56
# 57    745221    723882.38    21338.62           0.03       57
# 58  13296464  13613059.53   316595.53           0.02       58
# 59    732239    770610.45    38371.45           0.05       59
# 60    771579    705259.39    66319.61           0.09       60
# 61    768686    793606.99    24920.99           0.03       61
# 62    690661    703100.36    12439.36           0.02       62
# 63    910106    789992.65   120113.35           0.13       63
# 64    987956    980067.58     7888.42           0.01       64
# 65  10076195   9141599.46   934595.54           0.09       65
# 66    786108    910230.37   124122.37           0.16       66
# 67   1050273    764837.72   285435.28           0.27       67
# 68   1276030    892333.96   383696.04           0.30       68
# 69   1047441    790424.90   257016.10           0.25       69
# 70    802240    794656.57     7583.43           0.01       70
#
# [71 rows x 5 columns]

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 69.01%
# PRED (50): 98.59%

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Module']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:               E_Module   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     639.9
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):           9.49e-50
# Time:                        20:50:22   Log-Likelihood:                -669.08
# No. Observations:                  71   AIC:                             1344.
# Df Residuals:                      68   BIC:                             1351.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC            2.8985      0.979      2.961      0.004       0.945       4.852
#  NO           -0.1178      0.118     -1.002      0.320      -0.352       0.117
#  T_Module      0.1760      0.010     17.224      0.000       0.156       0.196
# ==============================================================================
# Omnibus:                       67.344   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              487.579
# Skew:                           2.771   Prob(JB):                    1.33e-106
# Kurtosis:                      14.580   Cond. No.                         148.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions.round(2), 'Difference':abs(Y - predictions).round(2), 'Percent Error':(abs(Y - predictions)/Y).round(2)}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#     Observed  Predicted  Difference  Percent Error  Version
# 0       5215    4938.77      276.23           0.05        0
# 1       5233    4778.64      454.36           0.09        1
# 2       6036    5164.08      871.92           0.14        2
# 3       6653    5497.51     1155.49           0.17        3
# 4       6197    5639.88      557.12           0.09        4
# 5       8957    5990.67     2966.33           0.33        5
# 6       8021    5870.02     2150.98           0.27        6
# 7       5868    5356.07      511.93           0.09        7
# 8       6463    5660.64      802.36           0.12        8
# 9       7563    5998.00     1565.00           0.21        9
# 10      7160    6234.76      925.24           0.13       10
# 11      9362    7871.46     1490.54           0.16       11
# 12      9568    8730.07      837.93           0.09       12
# 13      8518    8268.94      249.06           0.03       13
# 14     12282    8130.04     4151.96           0.34       14
# 15      9503    8066.23     1436.77           0.15       15
# 16     10112    9175.23      936.77           0.09       16
# 17      9911    9572.57      338.43           0.03       17
# 18      8836    8905.29       69.29           0.01       18
# 19     10233    9063.71     1169.29           0.11       19
# 20      9632    8681.10      950.90           0.10       20
# 21     10988    8746.68     2241.32           0.20       21
# 22      8869    9298.81      429.81           0.05       22
# 23      9155    9357.71      202.71           0.02       23
# 24     10909   10207.16      701.84           0.06       24
# 25      8706    9330.94      624.94           0.07       25
# 26     10645    9204.17     1440.83           0.14       26
# 27      7949    9277.63     1328.63           0.17       27
# 28      8847    8943.42       96.42           0.01       28
# 29     35494   35541.13       47.13           0.00       29
# ..       ...        ...         ...            ...      ...
# 41      9443    9505.68       62.68           0.01       41
# 42      8266   10116.38     1850.38           0.22       42
# 43     13561   10752.95     2808.05           0.21       43
# 44     11285   10416.28      868.72           0.08       44
# 45     10983   10784.25      198.75           0.02       45
# 46     35998   41419.06     5421.06           0.15       46
# 47      9965   11211.38     1246.38           0.13       47
# 48     37904   36337.52     1566.48           0.04       48
# 49     12531   13150.14      619.14           0.05       49
# 50     12435   13710.58     1275.58           0.10       50
# 51     10795   13601.47     2806.47           0.26       51
# 52     23240   13848.45     9391.55           0.40       52
# 53     13239   14386.94     1147.94           0.09       53
# 54     12087   14091.70     2004.70           0.17       54
# 55     14304   13498.76      805.24           0.06       55
# 56     12996   14036.72     1040.72           0.08       56
# 57     11637   13601.94     1964.94           0.17       57
# 58     59786   63460.35     3674.35           0.06       58
# 59     10076   12187.85     2111.85           0.21       59
# 60     10648   12046.73     1398.73           0.13       60
# 61     10144   12522.71     2378.71           0.23       61
# 62      9844   12282.28     2438.28           0.25       62
# 63     11441   12832.53     1391.53           0.12       63
# 64     11211   13736.29     2525.29           0.23       64
# 65     55000   46337.56     8662.44           0.16       65
# 66     11893   14889.70     2996.70           0.25       66
# 67     30602   14294.00    16308.00           0.53       67
# 68     13254   14982.81     1728.81           0.13       68
# 69     12481   14585.43     2104.43           0.17       69
# 70     11662   14755.44     3093.44           0.27       70
#
# [71 rows x 5 columns]

# %%
pred25 = calculate_PRED(0.25, results)
print("PRED (25): " + "{:.2%}".format(pred25))

pred50 = calculate_PRED(0.50, results)
print("PRED (50): " + "{:.2%}".format(pred50))
# Out:
# PRED (25): 87.32%
# PRED (50): 98.59%

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)
