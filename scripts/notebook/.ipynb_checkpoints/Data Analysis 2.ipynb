# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
# %matplotlib inline

# %%
df = pd.read_csv("../../output/data_analysis_major_versions.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
#df = pd.read_csv("../../output/data_analysis_rc.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()
#df.dtypes
# Out:
#                NC            NO      E_Module         E_Line      T_Module  \
# count  487.000000    487.000000    487.000000     487.000000    487.000000
# mean    76.462012    261.082136    454.971253   12405.887064  42495.850103
# std     51.812757    495.651678    953.500227   39116.617437  15097.308236
# min      4.000000     18.000000     22.000000     310.000000  17317.000000
# 25%     51.000000    157.500000    198.000000    3135.500000  29099.500000
# 50%     71.000000    220.000000    285.000000    4857.000000  43010.000000
# 75%     94.000000    287.500000    400.000000    9214.500000  56227.000000
# max    905.000000  10772.000000  12798.000000  754652.000000  67330.000000
#
#              T_Line
# count  4.870000e+02
# mean   1.707460e+07
# std    6.338985e+06
# min    6.738615e+06
# 25%    1.194979e+07
# 50%    1.694011e+07
# 75%    2.233763e+07
# max    2.816528e+07

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line   T_Module    T_Line
#  NC        1.000000  0.853381   0.485323  0.754767   0.004279  0.012653
#  NO        0.853381  1.000000   0.541405  0.909483   0.041384  0.048463
#  E_Module  0.485323  0.541405   1.000000  0.574750   0.049861  0.057430
#  E_Line    0.754767  0.909483   0.574750  1.000000  -0.074610 -0.065840
#  T_Module  0.004279  0.041384   0.049861 -0.074610   1.000000  0.998669
#  T_Line    0.012653  0.048463   0.057430 -0.065840   0.998669  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC', ' NO', ' T_Module']]
Y = df[' E_Line']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:                 E_Line   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     1398.
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):          4.90e-202
# Time:                        00:42:50   Log-Likelihood:                -5398.1
# No. Observations:                 487   AIC:                         1.080e+04
# Df Residuals:                     485   BIC:                         1.081e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NO           72.6861      1.434     50.705      0.000      69.869      75.503
#  T_Module     -0.1700      0.018     -9.554      0.000      -0.205      -0.135
# ==============================================================================
# Omnibus:                      638.333   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            80959.638
# Skew:                           6.513   Prob(JB):                         0.00
# Kurtosis:                      64.807   Cond. No.                         90.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#      Observed      Predicted  Version
# 0       43087   16222.396467        0
# 1       48137   40528.127525        1
# 2       17620   10184.225008        2
# 3       32921   17255.625403        3
# 4       14020   12255.999507        4
# 5      118434   31131.840013        5
# 6      162559   34537.933533        6
# 7        9065    9284.268632        7
# 8        3807    2930.197255        8
# 9        6757    9920.900230        9
# 10      22347   18664.103114       10
# 11      30714   20941.145143       11
# 12      15347    8016.011121       12
# 13       4547    4941.307671       13
# 14      51713   26801.350269       14
# 15       6239   10039.154417       15
# 16       1779    1389.179369       16
# 17       9559    4473.702820       17
# 18      10991   10603.633116       18
# 19       1694    3505.665919       19
# 20      67329   47121.152304       20
# 21      24428   32892.752612       21
# 22       8673   10414.112606       22
# 23       6263    7873.920831       23
# 24       6615   10674.043946       24
# 25      76297   36137.724018       25
# 26       8243   10085.304031       26
# 27      19218   21724.930458       27
# 28       8760   12159.786521       28
# 29       3685    5896.340505       29
# ..        ...            ...      ...
# 457     34019   14192.636973      457
# 458     78101   13051.991910      458
# 459     40444   15602.999313      459
# 460      3160    2678.288535      460
# 461     37111   15464.738375      461
# 462      1858   -1378.494365      462
# 463      8819   13079.107968      463
# 464      4898    8659.459995      464
# 465      7745   19355.758559      465
# 466      2255   -1141.453075      466
# 467      4518    6494.268366      467
# 468      4462   10291.509107      468
# 469      1660   -5774.658030      469
# 470      4425    5630.650052      470
# 471      8089   12037.515567      471
# 472      4973    8416.888270      472
# 473      3649    4578.565222      473
# 474      6147   10282.351632      474
# 475      6548    6289.601741      475
# 476      7479    2185.508471      476
# 477      4873    6684.397812      477
# 478      9520   21902.390398      478
# 479      1393   -6365.186126      479
# 480      2299   -1593.646358      480
# 481      2441    5140.717216      481
# 482      4549    8727.494407      482
# 483    754652  773679.942611      483
# 484     14498   12599.370533      484
# 485      8532   13084.985412      485
# 486      3889    2767.825766      486
#
# [487 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC',' NO', ' T_Line']]
Y = df[' E_Module']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:               E_Module   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.423
# Method:                 Least Squares   F-statistic:                     120.2
# Date:                Tue, 17 Mar 2020   Prob (F-statistic):           3.45e-58
# Time:                        00:43:41   Log-Likelihood:                -3945.9
# No. Observations:                 487   AIC:                             7898.
# Df Residuals:                     484   BIC:                             7910.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC            1.7019      1.089      1.563      0.119      -0.437       3.841
#  NO            0.8871      0.126      7.026      0.000       0.639       1.135
#  T_Line     5.417e-06   3.63e-06      1.491      0.137   -1.72e-06    1.26e-05
# ==============================================================================
# Omnibus:                      855.463   Durbin-Watson:                   1.582
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           418409.346
# Skew:                          10.884   Prob(JB):                         0.00
# Kurtosis:                     144.936   Cond. No.                     5.48e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.48e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#      Observed     Predicted  Version
# 0         588    396.994219        0
# 1        1296    814.081067        1
# 2         330    309.736397        2
# 3         344    396.494880        3
# 4         359    253.937452        4
# 5        1254    671.435902        5
# 6        1123    657.286197        6
# 7         272    273.821381        7
# 8         158    175.125993        8
# 9         330    369.283309        9
# 10        629    389.631875       10
# 11        657    514.095608       11
# 12        399    265.554316       12
# 13        180    200.664811       13
# 14        860    606.593698       14
# 15        280    276.461927       15
# 16        112    127.782725       16
# 17        183    190.966276       17
# 18        345    311.259590       18
# 19        118    156.927950       19
# 20       1227    943.790814       20
# 21        933    711.364452       21
# 22        333    318.229206       22
# 23        241    269.044736       23
# 24        366    386.723859       24
# 25        999    708.521653       25
# 26        317    313.567307       26
# 27        581    503.758500       27
# 28        330    396.434281       28
# 29        211    248.389235       29
# ..        ...           ...      ...
# 457      5301    581.195139      457
# 458      8220    608.626805      458
# 459      3906    596.335305      459
# 460       209    407.544887      460
# 461      5474    652.621502      461
# 462       157    334.597303      462
# 463       584    553.840070      463
# 464       306    487.704344      464
# 465       517    735.672757      465
# 466       173    368.169141      466
# 467       304    489.727414      467
# 468       321    529.714351      468
# 469        49    226.619238      469
# 470       293    430.678303      470
# 471       396    569.228741      471
# 472       358    574.335546      472
# 473       246    492.762082      473
# 474       429    557.509795      474
# 475       294    522.692167      475
# 476       195    385.598223      476
# 477       423    470.777073      477
# 478       571    829.099846      478
# 479        62    217.005598      479
# 480       197    337.807563      480
# 481       244    439.204440      481
# 482       291    534.570562      482
# 483     10668  11249.449343      483
# 484       381    569.445435      484
# 485       412    592.104025      485
# 486       218    406.609244      486
#
# [487 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)
