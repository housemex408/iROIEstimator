# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
# %matplotlib inline

# %%
df = pd.read_csv("../../output/data_analysis_part2_cleaned.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
#df = pd.read_csv("../../output/data_analysis_cleaned.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()
#df.dtypes
# Out:
#                  NC             NO      E_Module        E_Line      T_Module  \
# count    558.000000     558.000000    558.000000  5.580000e+02    558.000000
# mean     402.207885    2785.268817   2031.870968  1.961050e+05  42452.887097
# std     1810.422799   14932.822036   5501.266091  9.077149e+05  15106.879711
# min        4.000000      18.000000     22.000000  3.100000e+02  17317.000000
# 25%       54.000000     165.250000    209.000000  3.361250e+03  29097.750000
# 50%       77.000000     238.500000    310.500000  5.746000e+03  42718.500000
# 75%      108.000000     349.500000    545.500000  1.666300e+04  56227.500000
# max    27695.000000  236064.000000  59786.000000  1.329646e+07  67330.000000
#
#              T_Line
# count  5.580000e+02
# mean   1.705653e+07
# std    6.342633e+06
# min    6.738615e+06
# 25%    1.194885e+07
# 50%    1.681202e+07
# 75%    2.233769e+07
# max    2.816528e+07

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line   T_Module    T_Line
#  NC        1.000000  0.997216   0.882930  0.991823   0.084492  0.085491
#  NO        0.997216  1.000000   0.874578  0.988255   0.099758  0.100815
#  E_Module  0.882930  0.874578   1.000000  0.912230   0.105318  0.107506
#  E_Line    0.991823  0.988255   0.912230  1.000000   0.076739  0.078618
#  T_Module  0.084492  0.099758   0.105318  0.076739   1.000000  0.998675
#  T_Line    0.085491  0.100815   0.107506  0.078618   0.998675  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC',' NO', ' T_Module']]
Y = df[' E_Line']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:                 E_Line   R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                 1.181e+04
# Date:                Mon, 16 Mar 2020   Prob (F-statistic):               0.00
# Time:                        23:34:04   Log-Likelihood:                -7295.2
# No. Observations:                 558   AIC:                         1.460e+04
# Df Residuals:                     555   BIC:                         1.461e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC          566.7920     34.846     16.266      0.000     498.345     635.239
#  NO           -8.4257      4.229     -1.993      0.047     -16.732      -0.120
#  T_Module     -0.2089      0.118     -1.769      0.077      -0.441       0.023
# ==============================================================================
# Omnibus:                      258.385   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            41841.824
# Skew:                           0.902   Prob(JB):                         0.00
# Kurtosis:                      45.384   Cond. No.                         324.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#      Observed      Predicted  Version
# 0       43087   34366.145409        0
# 1       48137   69469.799009        1
# 2       17620   30521.946350        2
# 3       32921   30280.083988        3
# 4      573223  392090.416696        4
# 5       14020    5318.550444        5
# 6      118434   60821.586448        6
# 7      162559   43411.925901        7
# 8        9065   21978.336045        8
# 9        3807   15918.081228        9
# 10       6757   48481.704455       10
# 11     495661  344601.142638       11
# 12      22347   21397.279503       12
# 13      30714   50542.489135       13
# 14      15347   23743.113769       14
# 15       4547   15609.664692       15
# 16     618119  426659.989734       16
# 17      51713   56003.352499       17
# 18       6239   18900.011977       18
# 19       1779    6316.508944       19
# 20       9559   13880.867820       20
# 21      10991   27317.635256       21
# 22       1694    7205.748810       22
# 23     571144  479387.642926       23
# 24      67329   81294.060536       24
# 25      24428   64256.324984       25
# 26       8673   29501.091553       26
# 27       6263   24136.913226       27
# 28       6615   49263.398178       28
# 29     581403  502601.932195       29
# ..        ...            ...      ...
# 528      3160   20098.826997      528
# 529     37111   46344.709910      529
# 530      1858   13208.704400      530
# 531   1276030  876427.811134      531
# 532      8819   24410.545111      532
# 533      4898   20956.966382      533
# 534      7745   55925.676660      534
# 535      2255   21510.995991      535
# 536      4518   29686.547980      536
# 537      4462   27556.254459      537
# 538      1660   -3971.848400      538
# 539   1047441  785577.878820      539
# 540      4425   14418.247484      540
# 541      8089   32347.849340      541
# 542      4973   47463.386853      542
# 543      3649   37157.750271      543
# 544      6147   35374.972674      544
# 545      6548   39786.987270      545
# 546      7479   13679.833770      546
# 547    802240  787603.079090      547
# 548      4873   21470.455028      548
# 549      9520   72885.369046      549
# 550      1393   -6445.653002      550
# 551      2299   12235.269635      551
# 552      2441   17686.395236      552
# 553      4549   33110.011060      553
# 554    754652  408121.550899      554
# 555     14498   27955.704800      555
# 556      8532   32988.591737      556
# 557      3889   15505.549818      557
#
# [558 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')
df.plot.scatter(x=' T_Module', y=' E_Line', c='orange')
df.plot.scatter(x=' T_Line', y=' E_Line', c='orange')

# %%
# Let's create multiple regression
X = df[[' NC',' NO', ' T_Module']]
Y = df[' E_Module']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:               E_Module   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.813
# Method:                 Least Squares   F-statistic:                     807.6
# Date:                Mon, 16 Mar 2020   Prob (F-statistic):          5.85e-202
# Time:                        23:34:15   Log-Likelihood:                -5164.2
# No. Observations:                 558   AIC:                         1.033e+04
# Df Residuals:                     555   BIC:                         1.035e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC            6.2686      0.765      8.195      0.000       4.766       7.771
#  NO           -0.4375      0.093     -4.713      0.000      -0.620      -0.255
#  T_Module      0.0173      0.003      6.661      0.000       0.012       0.022
# ==============================================================================
# Omnibus:                      467.390   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17291.144
# Skew:                           3.403   Prob(JB):                         0.00
# Kurtosis:                      29.408   Cond. No.                         324.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#      Observed    Predicted  Version
# 0         588   626.864320        0
# 1        1296   898.673415        1
# 2         330   613.785692        2
# 3         344   578.039111        3
# 4        5215  3450.169017        4
# 5         359   334.885414        5
# 6        1254   856.778158        6
# 7        1123   654.644473        7
# 8         272   537.945459        8
# 9         158   501.237104        9
# 10        330   825.658501       10
# 11       5233  3032.212250       11
# 12        629   493.949894       12
# 13        657   802.806009       13
# 14        399   569.570466       14
# 15        180   494.979792       15
# 16       6036  3482.015201       16
# 17        860   842.743365       17
# 18        280   514.326732       18
# 19        112   416.814156       19
# 20        183   485.326135       20
# 21        345   603.981634       21
# 22        118   416.664564       22
# 23       6653  4008.719775       23
# 24       1227  1033.036610       24
# 25        933   912.947498       25
# 26        333   637.109007       26
# 27        241   590.137245       27
# 28        366   852.539771       28
# 29       6197  4134.007139       29
# ..        ...          ...      ...
# 528       209  1423.293505      528
# 529      5474  1651.428920      529
# 530       157  1366.910078      530
# 531     13254  6115.372232      531
# 532       584  1434.794528      532
# 533       306  1417.600209      533
# 534       517  1750.984347      534
# 535       173  1469.498967      535
# 536       304  1523.424556      536
# 537       321  1482.324471      537
# 538        49  1211.782032      538
# 539     12481  5069.964750      539
# 540       293  1368.279533      540
# 541       396  1534.845001      541
# 542       358  1717.533609      542
# 543       246  1622.490666      543
# 544       429  1576.302047      544
# 545       294  1643.541625      545
# 546       195  1376.372815      546
# 547     11662  5197.385697      547
# 548       423  1455.487448      548
# 549       571  1948.178246      549
# 550        62  1210.589570      550
# 551       197  1393.117289      551
# 552       244  1421.386872      552
# 553       291  1573.722587      553
# 554     10668  2123.017720      554
# 555       381  1514.719716      555
# 556       412  1567.706773      556
# 557       218  1424.327678      557
#
# [558 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)
