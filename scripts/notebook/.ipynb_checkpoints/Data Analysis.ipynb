# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
import statsmodels as sm
import statsmodels.api as smapi
import statsmodels.regression.linear_model as lm
# %matplotlib inline

# %%
df = pd.read_csv("../../output/data_analysis.csv")
# This has the releases with zero NC/NO removed
# Need to investigate to see why this happens in all -rc1 releases
#df = pd.read_csv("../../output/data_analysis_cleaned.csv")
df[" E_Line"] = df[" E_Line"].astype(str).astype(int)
df[" E_Module"] = df[" E_Module"].astype(str).astype(int)
df[" NC"] = df[" NC"]
df[" NO"] = df[" NO"]

# %%
df.describe()
# Out:
#                  NC             NO      E_Module        E_Line
# count    638.000000     638.000000    638.000000  6.380000e+02
# mean     351.774295    2436.018809   2329.576803  2.362711e+05
# std     1698.165608   13994.154828   6355.299396  1.175350e+06
# min        0.000000       0.000000      0.000000  0.000000e+00
# 25%       43.250000     133.000000    222.250000  3.641500e+03
# 50%       70.000000     218.000000    342.500000  6.751500e+03
# 75%      102.000000     319.750000   1381.250000  3.221300e+04
# max    27695.000000  236064.000000  59786.000000  1.329646e+07

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                  NC        NO   E_Module    E_Line
#  NC        1.000000  0.997152   0.702754  0.706966
#  NO        0.997152  1.000000   0.698210  0.706177
#  E_Module  0.702754  0.698210   1.000000  0.923956
#  E_Line    0.706966  0.706177   0.923956  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')

# %%
# Let's create multiple regression
X = df[[' NC',' NO']]
Y = df[' E_Line']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:                 E_Line   R-squared:                       0.517
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     339.8
# Date:                Sun, 15 Mar 2020   Prob (F-statistic):          4.23e-101
# Time:                        22:35:32   Log-Likelihood:                -9603.0
# No. Observations:                 638   AIC:                         1.921e+04
# Df Residuals:                     636   BIC:                         1.922e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC          545.6613    236.326      2.309      0.021      81.587    1009.736
#  NO           -5.9818     28.853     -0.207      0.836     -62.641      50.677
# ==============================================================================
# Omnibus:                     1254.664   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1146745.492
# Skew:                          14.233   Prob(JB):                         0.00
# Kurtosis:                     208.736   Cond. No.                         103.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#      Observed      Predicted  Version
# 0      143623       0.000000        0
# 1       43087   37138.816805        1
# 2       48137   71664.295482        2
# 3       17620   33270.019745        3
# 4       32921   33241.423756        4
# 5      573223  388784.697818        5
# 6      311270       0.000000        6
# 7       14020    9129.322281        7
# 8      118434   63159.711744        8
# 9      162559   46538.635430        9
# 10       9065   25162.864376       10
# 11       3807   19141.331382       11
# 12       6757   50713.235542       12
# 13     495661  342513.203373       13
# 14      72359       0.000000       14
# 15      22347   24942.849292       15
# 16      30714   53083.944444       16
# 17      15347   26895.557798       17
# 18       4547   18973.839675       18
# 19     618119  424465.841649       19
# 20      79895       0.000000       20
# 21      51713   58595.707225       21
# 22       6239   22368.757603       22
# 23       1779    9996.690049       23
# 24       9559   17372.746880       24
# 25      10991   30493.858513       25
# 26       1694   10914.539079       26
# 27     571144  475718.756636       27
# 28     110207       0.000000       28
# 29      67329   83634.266065       29
# ..        ...            ...      ...
# 608   1276030  886915.115608      608
# 609     35090       0.000000      609
# 610      8819   37325.567296      610
# 611      4898   33870.830901      611
# 612      7745   67865.967339      612
# 613      2255   34120.755218      613
# 614      4518   42217.260138      614
# 615      4462   40275.202082      615
# 616      1660    9439.065064      616
# 617   1047441  799845.227433      617
# 618     34796       0.000000      618
# 619      4425   27574.132960      619
# 620      8089   45030.625694      620
# 621      4973   59487.002381      621
# 622      3649   49448.439405      622
# 623      6147   47896.514627      623
# 624      6548   52033.181543      624
# 625      7479   26763.957171      625
# 626    802240  801400.507570      626
# 627     28317       0.000000      627
# 628      4873   34560.056513      628
# 629      9520   84530.229823      629
# 630      1393    7292.310977      630
# 631      2299   25426.065630      631
# 632      2441   30872.028098      632
# 633      4549   45833.506393      633
# 634    754652  429387.016605      634
# 635     14498   41151.178185      635
# 636      8532   46014.275037      636
# 637      3889   28874.820178      637
#
# [638 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)

# %%
df.plot.scatter(x=' NC', y=' E_Line', c='red')
df.plot.scatter(x=' NO', y=' E_Line', c='green')

# %%
# Let's create multiple regression
X = df[[' NC',' NO']]
Y = df[' E_Module']
#X = smapi.add_constant(X)
model = lm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# OLS Regression Results
# ==============================================================================
# Dep. Variable:               E_Module   R-squared:                       0.524
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     350.5
# Date:                Sun, 15 Mar 2020   Prob (F-statistic):          2.50e-103
# Time:                        22:35:42   Log-Likelihood:                -6295.1
# No. Observations:                 638   AIC:                         1.259e+04
# Df Residuals:                     636   BIC:                         1.260e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
#  NC            8.0151      1.324      6.055      0.000       5.416      10.614
#  NO           -0.6395      0.162     -3.957      0.000      -0.957      -0.322
# ==============================================================================
# Omnibus:                      960.926   Durbin-Watson:                   1.716
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           253353.597
# Skew:                           8.490   Prob(JB):                         0.00
# Kurtosis:                      99.136   Cond. No.                         103.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
data = {'Observed':Y, 'Predicted':predictions}
results = pd.DataFrame(data) 
results['Version'] = np.arange(results.__len__())
results
# Out:
#      Observed    Predicted  Version
# 0        2255     0.000000        0
# 1         588   397.698211        1
# 2        1296   717.294467        2
# 3         330   386.652650        3
# 4         344   333.279233        4
# 5        5215  3723.392427        5
# 6        2976     0.000000        6
# 7         359    19.918499        7
# 8        1254   663.528040        8
# 9        1123   396.216497        9
# 10        272   274.738658       10
# 11        158   234.829878       11
# 12        330   641.218579       12
# 13       5233  3204.784058       13
# 14       1659     0.000000       14
# 15        629   200.902389       15
# 16        657   592.750312       16
# 17        399   309.015489       17
# 18        180   216.924883       18
# 19       6036  3663.365353       19
# 20       1595     0.000000       20
# 21        860   628.480742       21
# 22        280   227.628878       22
# 23        112   112.640792       23
# 24        183   196.716262       24
# 25        345   341.461262       25
# 26        118   110.126603       26
# 27       6653  4311.959603       27
# 28       2578     0.000000       28
# 29       1227   839.614556       29
# ..        ...          ...      ...
# 608     13254  5248.578293      608
# 609      2025     0.000000      609
# 610       584   367.345501      610
# 611       306   350.246865      611
# 612       517   764.098573      612
# 613       173   427.280454      613
# 614       304   487.739421      614
# 615       321   431.081347      615
# 616        49   103.346729      616
# 617     12481  3890.743593      617
# 618      1899     0.000000      618
# 619       293   280.922736      619
# 620       396   486.591496      620
# 621       358   723.760891      621
# 622       246   606.643850      622
# 623       429   541.374845      623
# 624       294   631.372387      624
# 625       195   294.947279      625
# 626     11662  4057.004257      626
# 627      1764     0.000000      627
# 628       423   373.609138      628
# 629       571   985.710267      629
# 630        62    75.122973      630
# 631       197   302.875078      631
# 632       244   331.571403      632
# 633       291   522.103587      633
# 634     10668   365.390025      634
# 635       381   424.090910      635
# 636       412   491.111413      636
# 637       218   319.334250      637
#
# [638 rows x 3 columns]

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
partialRegPlot = plt.figure(figsize=(15,8))
partialRegPlot = sm.graphics.regressionplots.plot_partregress_grid(model, fig=partialRegPlot)

# %%
regPlotNC = plt.figure(figsize=(15,8))
regPlotNC = sm.graphics.regressionplots.plot_regress_exog(model, " NC", fig=regPlotNC)

# %%
regPlotNO = plt.figure(figsize=(15,8))
regPlotNO = sm.graphics.regressionplots.plot_regress_exog(model, " NO", fig=regPlotNO)
