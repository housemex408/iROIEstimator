# %%
import pandas as pd
from pandas import datetime
from pandas import DataFrame
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from pmdarima.arima import auto_arima
from plotly.offline import plot_mpl
from statsmodels.tsa.seasonal import seasonal_decompose
from math import sqrt
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
variable = ' E_Module'
releaseDate = ' Release Date'

df = pd.read_csv("../../output/data_analysis_major_versions_with_dates.csv", usecols=[variable, releaseDate])
df[releaseDate] = pd.to_datetime(df[releaseDate])
df = df.set_index(releaseDate)
df.index = df.index.strftime('%Y-%m-%d') 
df.head()
# Out:
#                 E_Module
#  Release Date
# 2005-08-28          5215
# 2005-10-27          5223
# 2006-01-02          6026
# 2006-03-19          6641
# 2006-06-17          6167

# %%
train = df[0:55] # 55 observations in train data
test = df[55:] # 19 observations in test data

# %%
result = seasonal_decompose(train, model='additive', period=12)
fig = result.plot()
plot_mpl(fig)
# Out:
# 'temp-plot.html'

# %%
arima_model = auto_arima(train, m=12)
print(arima_model.aic())
# Out:
# 935.8424644436242

# %%
forecast = arima_model.predict(n_periods=len(test))
data = {variable: forecast, releaseDate: test.index} 
forecast = pd.DataFrame(data) 
forecast = forecast.set_index(releaseDate)

# %%
#plot the predictions for validation set
plt.figure(figsize=(22, 10))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test', color='r')
plt.plot(forecast.index, forecast, label='SARIMA', color='k')
plt.legend(loc='best', fontsize='xx-large')
plt.show()

# %%
#calculate rmse
mse = mean_squared_error(test,forecast)
print(mse)

rms = sqrt(mse)
print(rms)

mae = mean_absolute_error(test,forecast)
print(mae)
# Out:
# 27715266.423739344
# 5264.529079009759
# 2528.266483462116

# %%
simple_series = pd.Series(df[variable], df.index)


simple_smoothing_model = SimpleExpSmoothing(simple_series).fit()
simple_forecast = simple_smoothing_model.forecast(12).rename(r'$\alpha=%s$'%simple_smoothing_model.model.params['smoothing_level'])
# plot
simple_forecast.plot(marker='o', color='green', legend=True)
simple_smoothing_model.fittedvalues.plot(marker='o', color='green')

plt.show()
# Out:
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
holt_model = Holt(simple_series, damped=True).fit(smoothing_level=0.8, smoothing_slope=0.2)
holt_forecast = holt_model.forecast(12).rename("Additive damped trend")

holt_model.fittedvalues.plot(marker="o", color='green')
holt_forecast.plot(color='green', marker="o", legend=True)

plt.show()
# Out:
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
holt_winters_add = ExponentialSmoothing(simple_series, seasonal_periods=12, trend='add', seasonal='add').fit(use_boxcox=True)
holt_winters_mul = ExponentialSmoothing(simple_series, seasonal_periods=12, trend='add', seasonal='mul').fit(use_boxcox=True)

holt_winters_add.fittedvalues.plot(style='--', color='red')
holt_winters_mul.fittedvalues.plot(style='--', color='green')

holt_winters_add.forecast(12).plot(style='--', marker='o', color='red', legend=True)
holt_winters_mul.forecast(12).plot(style='--', marker='o', color='green', legend=True)

plt.show()
# Out:
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
holt_winters_add = ExponentialSmoothing(train, seasonal_periods=12, trend='add', seasonal='add').fit(use_boxcox=True)
predictions = holt_winters_add.forecast(19).rename('Forecast')

data = {variable: predictions, releaseDate: test.index} 
forecast = pd.DataFrame(data) 
forecast = forecast.set_index(releaseDate)

plt.figure(figsize=(22, 10))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test', color='r')
plt.plot(forecast.index, forecast, label='Holt-Winters', color='k')
plt.legend(loc='best', fontsize='xx-large')
plt.show()
# Out:
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# /Users/housemex408/.conda/envs/PRAXIS/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.

# %%
mse = mean_squared_error(test,forecast)
print(mse)

rms = sqrt(mse)
print(rms)

mae = mean_absolute_error(test,forecast)
print(mae)
# Out:
# 36033570.04370987
# 6002.7968517775
# 3791.5150243407934

# %%
from fbprophet import Prophet
import logging
logging.getLogger().setLevel(logging.ERROR)

# %%
simple_series = simple_series.reset_index()
simple_series.columns = ['ds', 'y']

# %%
m = Prophet()
m.fit(simple_series)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=12)
# future.tail()

# %%
forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
fig1 = m.plot(forecast)

# %%
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics

cross_validation_results = cross_validation(m, horizon='365 days')
print(cross_validation_results)

performance_metrics_results = performance_metrics(cross_validation_results)
print(performance_metrics_results)
# Out:
# INFO:fbprophet:Making 21 forecasts with cutoffs between 2009-01-28 00:00:00 and 2019-01-26 00:00:00
# INFO:fbprophet:n_changepoints greater than number of observations. Using 11.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 13.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 16.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 21.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-20-6a76dd6199d1> in <module>
#       2 from fbprophet.diagnostics import performance_metrics
#       3
# ----> 4 cross_validation_results = cross_validation(m, horizon='365 days')
#       5 print(cross_validation_results)
#       6
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/fbprophet/diagnostics.py in cross_validation(model, horizon, period, initial)
#     118                 'Increase initial window.'
#     119             )
# --> 120         m.fit(history_c, **model.fit_kwargs)
#     121         # Calculate yhat
#     122         index_predicted = (df['ds'] > cutoff) & (df['ds'] <= cutoff + horizon)
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/fbprophet/forecaster.py in fit(self, df, **kwargs)
#    1139             self.params = self.stan_backend.sampling(stan_init, dat, self.mcmc_samples, **kwargs)
#    1140         else:
# -> 1141             self.params = self.stan_backend.fit(stan_init, dat, **kwargs)
#    1142
#    1143         # If no changepoints were requested, replace delta with 0s
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/fbprophet/models.py in fit(self, stan_init, stan_data, **kwargs)
#     240         args.update(kwargs)
#     241         try:
# --> 242             params = self.model.optimizing(**args)
#     243         except RuntimeError:
#     244             # Fall back on Newton
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/pystan/model.py in optimizing(self, data, seed, init, sample_file, algorithm, verbose, as_vector, **kwargs)
#     579         stan_args = pystan.misc._get_valid_stan_args(stan_args)
#     580
# --> 581         ret, sample = fit._call_sampler(stan_args)
#     582         pars = pystan.misc._par_vector2dict(sample['par'], m_pars, p_dims)
#     583         if not as_vector:
#
# stanfit4anon_model_888a84912910fa0a45b9d614b75bb8a8_8861480549659362852.pyx in stanfit4anon_model_888a84912910fa0a45b9d614b75bb8a8_8861480549659362852.StanFit4Model._call_sampler()
#
# stanfit4anon_model_888a84912910fa0a45b9d614b75bb8a8_8861480549659362852.pyx in stanfit4anon_model_888a84912910fa0a45b9d614b75bb8a8_8861480549659362852._call_sampler()
#
# stanfit4anon_model_888a84912910fa0a45b9d614b75bb8a8_8861480549659362852.pyx in stanfit4anon_model_888a84912910fa0a45b9d614b75bb8a8_8861480549659362852._pystanholder_from_stanholder()
#
# SystemError: <class 'stanfit4anon_model_888a84912910fa0a45b9d614b75bb8a8_8861480549659362852.PyStanHolder'> returned a result with an error set
