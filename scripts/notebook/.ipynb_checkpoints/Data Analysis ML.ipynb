# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
sys.path.append('../../')
import Constants as c
import Utilities as utils
from sklearn.tree import DecisionTreeRegressor
from sklearn import model_selection
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
# %matplotlib inline

# %%
df = pd.read_csv("../../exports/angular/angular_dataset_BUG.csv")
df["E_Line"] = df["E_Line"]
df["E_Module"] = df["E_Module"]
df["NC"] = df["NC"]
df["NO"] = df["NO"]

df = utils.isRegularVersion(df)

if df.isna().values.any():
    df.fillna(df.median(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'E_Line'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-541a5314dc79> in <module>
#       1 df = pd.read_csv("../../exports/angular/angular_dataset_BUG.csv")
# ----> 2 df["E_Line"] = df["E_Line"]
#       3 df["E_Module"] = df["E_Module"]
#       4 df["NC"] = df["NC"]
#       5 df["NO"] = df["NO"]
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/.conda/envs/PRAXIS/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'E_Line'

# %%
# df.describe()

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8fda28268e31> in <module>
#       1 # print out a correlation matrix of our data frame
# ----> 2 corr = df.corr()
#       3
#       4 # display it
#       5 display(corr)
#
# NameError: name 'df' is not defined

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f816767df0a4> in <module>
# ----> 1 sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')
#
# NameError: name 'corr' is not defined

# %%
df.plot.scatter(x='NC', y='E_Line', c='red')
df.plot.scatter(x='NO', y='E_Line', c='green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-579dbd2c57c6> in <module>
# ----> 1 df.plot.scatter(x='NC', y='E_Line', c='red')
#       2 df.plot.scatter(x='NO', y='E_Line', c='green')
#
# NameError: name 'df' is not defined

# %%
# Let's create multiple regression
X = df[['NC','NO']]
Y = df['E_Line']

splits = 10
num_records = len(X)

if num_records <= splits:
    splits = num_records

model = DecisionTreeRegressor(random_state=0)
model.fit(X, Y)

kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e589f5cfc061> in <module>
#       1 # Let's create multiple regression
# ----> 2 X = df[['NC','NO']]
#       3 Y = df['E_Line']
#       4
#       5 splits = 10
#
# NameError: name 'df' is not defined

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
# results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fc7d629dbe76> in <module>
#       1 data = {}
# ----> 2 data[c.OBSERVED] = Y.round(2)
#       3 data[c.PREDICTED] = predictions.round(2)
#       4 data[c.DIFFERENCE] = abs(Y - predictions).round(2)
#       5 data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
#
# NameError: name 'Y' is not defined

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9752bc9c93ec> in <module>
# ----> 1 ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
#       2 results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
#
# NameError: name 'results' is not defined

# %%
df.plot.scatter(x='NC', y='E_Line', c='red')
df.plot.scatter(x='NO', y='E_Line', c='green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-579dbd2c57c6> in <module>
# ----> 1 df.plot.scatter(x='NC', y='E_Line', c='red')
#       2 df.plot.scatter(x='NO', y='E_Line', c='green')
#
# NameError: name 'df' is not defined

# %%
# Let's create multiple regression
X = df[['NC','NO', 'T_Module']]
Y = df['E_Module']

model = DecisionTreeRegressor(random_state=0)
model.fit(X, Y)

kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5c0227e643ec> in <module>
#       1 # Let's create multiple regression
# ----> 2 X = df[['NC','NO', 'T_Module']]
#       3 Y = df['E_Module']
#       4
#       5 model = DecisionTreeRegressor(random_state=0)
#
# NameError: name 'df' is not defined

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4d6438442fe8> in <module>
#       1 data = {}
# ----> 2 data[c.OBSERVED] = Y.round(2)
#       3 data[c.PREDICTED] = predictions.round(2)
#       4 data[c.DIFFERENCE] = abs(Y - predictions).round(2)
#       5 data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
#
# NameError: name 'Y' is not defined

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9752bc9c93ec> in <module>
# ----> 1 ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
#       2 results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
#
# NameError: name 'results' is not defined
