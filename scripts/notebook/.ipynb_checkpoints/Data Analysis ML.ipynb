# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
sys.path.append('../../')
import Constants as c
import Utilities as utils
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import model_selection
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
# %matplotlib inline

# %%
def get_NT(df, task_type):
    nt = pd.read_csv(file.format(directoryPath, project_name, project_name, task_type))
    if nt.isna().values.any():
        nt.fillna(0, inplace=True)
    df[c.NT + "_" + task_type] = nt[c.NT_CC] + nt[c.NT_EC] + nt[c.NT_UC]

# %%
directoryPath = "../../exports"
project_name = "ansible"
task = "BUG"
file = "{0}/{1}/{2}_dataset_{3}.csv"

df = pd.read_csv(file.format(directoryPath, project_name, project_name, task))

# df = utils.isRegularVersion(df)
get_NT(df, "DOCS")
get_NT(df, "REFACTOR")
get_NT(df, "TESTING")
get_NT(df, "FEATURE")
get_NT(df, "UPGRADE")
get_NT(df, "RELEASE")
get_NT(df, "SUPPORT")
get_NT(df, "OTHER")

df[c.DATE] = pd.to_datetime(df[c.DATE])
df['diff_hours'] = df[c.DATE].diff(-1) * (-1) / np.timedelta64(1, 'h')
df['year'] = df[c.DATE].dt.year
df['month'] = df[c.DATE].dt.month
df['day'] = df[c.DATE].dt.day
df['quarter'] = df[c.DATE].dt.quarter
df[c.NT] = df[c.NT_CC] + df[c.NT_EC] + df[c.NT_UC]
df[c.NO] = df[c.NO_CC] + df[c.NO_EC] + df[c.NO_UC]
df[c.LINE] = df[c.LINE_CC] + df[c.LINE_EC] + df[c.LINE_UC]
df[c.MODULE] = df[c.MODULE_CC] + df[c.MODULE_EC] + df[c.MODULE_UC]
df[c.T_CONTRIBUTORS] = df[c.T_CC] + df[c.T_EC] + df[c.T_UC] + 2
df.drop(df.columns[0], axis=1, inplace=True)
df.drop(c.DATE, axis=1, inplace=True)
df.drop(c.PROJECT, axis=1, inplace=True)
# df.drop(c.VERSION, axis=1, inplace=True)
# df.drop("f0_", axis=1, inplace=True)

if df.isna().values.any():
    df.fillna(df.median(), inplace=True)

#Capping the outlier rows with Percentiles
upper_lim = df[c.MODULE].quantile(.95)
lower_lim = df[c.MODULE].quantile(.05)
df.loc[(df[c.MODULE] > upper_lim),c.MODULE] = upper_lim
df.loc[(df[c.MODULE] < lower_lim),c.MODULE] = lower_lim

upper_lim = df[c.LINE].quantile(.95)
lower_lim = df[c.LINE].quantile(.05)
df.loc[(df[c.LINE] > upper_lim),c.LINE] = upper_lim
df.loc[(df[c.LINE] < lower_lim),c.LINE] = lower_lim


percent_25 = df[c.MODULE].quantile(.25)
percent_50 = df[c.MODULE].quantile(.50)
percent_75 = df[c.MODULE].quantile(.75)

df['Module_Bin'] = pd.cut(df[c.MODULE], bins=[df[c.MODULE].min(),percent_25,percent_50,percent_75, df[c.MODULE].max()], labels=[0, 1,2,3], duplicates='drop')
df.head()

percent_25 = df[c.LINE].quantile(.25)
percent_50 = df[c.LINE].quantile(.50)
percent_75 = df[c.LINE].quantile(.75)

df['Line_Bin'] = pd.cut(df[c.LINE], bins=[df[c.LINE].min(),percent_25,percent_50,percent_75, df[c.LINE].max()], labels=[0,1,2,3], duplicates='drop')
df.head()

conditions = [
    df[c.VERSION].str.contains('-rc'),
    df[c.VERSION].str.contains('-beta'),
    df[c.VERSION].str.contains('-alpha')
]

choices = [2, 3, 4]

df['Release'] = np.select(conditions, choices, default=1)

if df.isna().values.any():
    df.fillna(df.median(), inplace=True)

# %%
# df['NTDOCS']

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                 T_Module    T_Line     NT_CC     NO_CC  Module_CC   Line_CC  \
# T_Module        1.000000  0.998545  0.340497  0.300357   0.418103  0.448609
# T_Line          0.998545  1.000000  0.329378  0.306593   0.406667  0.440002
# NT_CC           0.340497  0.329378  1.000000  0.787359   0.967280  0.894308
# NO_CC           0.300357  0.306593  0.787359  1.000000   0.760199  0.756549
# Module_CC       0.418103  0.406667  0.967280  0.760199   1.000000  0.958189
# Line_CC         0.448609  0.440002  0.894308  0.756549   0.958189  1.000000
# T_CC            0.340497  0.329378  1.000000  0.787359   0.967280  0.894308
# NT_EC           0.364556  0.361282  0.829088  0.691225   0.872924  0.860231
# NO_EC           0.344325  0.342443  0.851662  0.808012   0.881793  0.890100
# Module_EC       0.412368  0.406631  0.785899  0.624023   0.839247  0.856857
# Line_EC         0.386228  0.380784  0.768318  0.590940   0.827029  0.826018
# T_EC            0.364556  0.361282  0.829088  0.691225   0.872924  0.860231
# NT_UC           0.271546  0.287683  0.434898  0.874937   0.432240  0.453010
# NO_UC           0.252868  0.269834  0.422120  0.873351   0.419050  0.448852
# Module_UC       0.426316  0.443469  0.387580  0.775292   0.429334  0.514404
# Line_UC         0.457133  0.472021  0.482852  0.806551   0.537347  0.636491
# T_UC                 NaN       NaN       NaN       NaN        NaN       NaN
# NT_DOCS         0.386542  0.380544  0.790618  0.690119   0.820842  0.796204
# NT_REFACTOR     0.289263  0.285695  0.729423  0.606793   0.742728  0.699743
# NT_TESTING      0.267217  0.266174  0.831103  0.771651   0.851044  0.811536
# NT_FEATURE      0.323274  0.317697  0.749549  0.749984   0.716414  0.745157
# NT_UPGRADE      0.397692  0.396153  0.798228  0.787652   0.848664  0.897396
# NT_RELEASE      0.100343  0.091436  0.514649  0.522518   0.446554  0.410135
# NT_SUPPORT      0.407131  0.406391  0.824770  0.805104   0.882260  0.940322
# NT_OTHER        0.358335  0.355794  0.863521  0.821910   0.892231  0.904703
# diff_hours     -0.162970 -0.152554 -0.103743 -0.035082  -0.113730 -0.081414
# year            0.848734  0.836718  0.362359  0.268581   0.407152  0.399948
# month           0.076303  0.077444  0.044446 -0.010051   0.066547  0.067445
# day             0.013566  0.011056  0.058431  0.070799   0.045195  0.034899
#
#                   Module  T_Contributors  Release
# T_Module        0.436149        0.347659      NaN
# T_Line          0.429909        0.346478      NaN
# NT_CC           0.786392        0.784827      NaN
# NO_CC           0.626687        0.650717      NaN
# Module_CC       0.851482        0.837356      NaN
# Line_CC         0.858769        0.833691      NaN
# T_CC            0.786392        0.784827      NaN
# NT_EC           0.940569        0.984421      NaN
# NO_EC           0.903792        0.947698      NaN
# Module_EC       0.964633        0.961480      NaN
# Line_EC         0.946832        0.971292      NaN
# T_EC            0.940569        0.984421      NaN
# NT_UC           0.354386        0.373767      NaN
# NO_UC           0.334784        0.357438      NaN
# Module_UC       0.382668        0.365165      NaN
# Line_UC         0.528777        0.517153      NaN
# T_UC                 NaN             NaN      NaN
# NT_DOCS         0.928546        0.926474      NaN
# NT_REFACTOR     0.816708        0.903550      NaN
# NT_TESTING      0.838141        0.894503      NaN
# NT_FEATURE      0.743964        0.715475      NaN
# NT_UPGRADE      0.896546        0.851490      NaN
# NT_RELEASE      0.370502        0.459155      NaN
# NT_SUPPORT      0.872753        0.900399      NaN
# NT_OTHER        0.894719        0.928630      NaN
# diff_hours     -0.074533       -0.070828      NaN
# year            0.385349        0.324013      NaN
# month           0.067954        0.038160      NaN
# day             0.082811        0.065135      NaN
# quarter         0.063271        0.027085      NaN
# NT              0.936313        0.998520      NaN
# NO              0.875731        0.934340      NaN
# Line            0.987058        0.953182      NaN
# Module          1.000000        0.937294      NaN
# T_Contributors  0.937294        1.000000      NaN
# Release              NaN             NaN      NaN
#
# [36 rows x 36 columns]

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=c.NT, y=c.LINE, c='red')
df.plot.scatter(x=c.NO, y=c.LINE, c='green')

# %%
# X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS, 'Line_Bin', 'quarter', 'Release', 'diff_hours', 'year', 'month', 'day']]
X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS, 'diff_hours',  'month', 'Release',
"NT_DOCS", "NT_REFACTOR", "NT_TESTING", "NT_FEATURE", "NT_UPGRADE", "NT_RELEASE", "NT_SUPPORT","NT_OTHER", 'Line_Bin' ]]
# X = df[[c.NT, c.NO, 'Line_Bin', c.T_CONTRIBUTORS ]]
Y = df[c.LINE]

splits = 10
num_records = len(X)

if num_records <= splits:
    splits = num_records

# model = DecisionTreeRegressor(random_state=0)
model = RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=0)
model.fit(X, Y)

kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
# results
# Out:
# 0.81
# 0.86

# %%
feature_importances = pd.DataFrame(model.feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                 importance
# T_Contributors    0.334406
# NT                0.312919
# NT_DOCS           0.154674
# NT_UPGRADE        0.109482
# NT_SUPPORT        0.068406
# NT_REFACTOR       0.009982
# NT_FEATURE        0.002701
# NT_TESTING        0.001728
# NT_RELEASE        0.001676
# NT_OTHER          0.000952
# Line_Bin          0.000807
# NO                0.000772
# T_Line            0.000709
# T_Module          0.000699
# diff_hours        0.000047
# month             0.000040
# Release           0.000000

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
df.plot.scatter(x=c.NT, y=c.MODULE, c='red')
df.plot.scatter(x=c.NO, y=c.MODULE, c='green')

# %%
# Let's create multiple regression
X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS, 'diff_hours',  'month', 'Release',
"NT_DOCS", "NT_REFACTOR", "NT_TESTING", "NT_FEATURE", "NT_UPGRADE", "NT_RELEASE", "NT_SUPPORT","NT_OTHER", 'Module_Bin' ]]
# X = df[[c.NT, c.NO,'Module_Bin', c.T_CONTRIBUTORS, c.T_MODULE  ]]
Y = df[c.MODULE]

splits = 10
num_records = len(X)


# model = DecisionTreeRegressor(random_state=0)
model = RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=0)
model.fit(X, Y)

kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
# Out:
# 0.83
# 0.89

# %%
feature_importances = pd.DataFrame(model.feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                 importance
# T_Contributors    0.514009
# NT                0.376964
# NT_DOCS           0.054178
# NT_UPGRADE        0.029796
# NT_RELEASE        0.006416
# T_Module          0.005630
# T_Line            0.005238
# NT_SUPPORT        0.003537
# NT_TESTING        0.001106
# NO                0.000936
# NT_OTHER          0.000703
# Module_Bin        0.000598
# NT_FEATURE        0.000399
# NT_REFACTOR       0.000293
# diff_hours        0.000111
# month             0.000088
# Release           0.000000

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
