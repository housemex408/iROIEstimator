# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
sys.path.append('../../')
import Constants as c
import Utilities as utils
from Scaler import Scaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import model_selection
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.compose import TransformedTargetRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import QuantileTransformer
from sklearn.pipeline import Pipeline
# %matplotlib inline
from sklearn.linear_model import RidgeCV

# %%
regressors = {
  "DecisionTreeRegressor": DecisionTreeRegressor(random_state=0),
  "RandomForestRegressor": RandomForestRegressor(random_state=0),
  "LinearRegression": LinearRegression(),
  "RidgeCV": RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1])
}

transformers = {
  "RobustScaler": RobustScaler(),
  "StandardScaler": StandardScaler(),
  "MinMaxScaler": MinMaxScaler(),
  "QuantileTransformer": QuantileTransformer()
}

regressor = regressors["DecisionTreeRegressor"]
transformer = transformers["QuantileTransformer"]
# df = utils.remove_outlier(df, c.LINE)
# df = utils.remove_outlier(df, c.MODULE)

if df.isna().values.any():
    df.fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-230-4d79d4e609f9> in <module>
#       2   "DecisionTreeRegressor": DecisionTreeRegressor(random_state=0),
#       3   "RandomForestRegressor": RandomForestRegressor(random_state=0),
# ----> 4   "KernelRidge": KernelRidge(),
#       5   "MLPRegressor": MLPRegressor(random_state=0),
#       6   "SVR": SVR(),
#
# NameError: name 'KernelRidge' is not defined

# %%
directoryPath = "../../exports"
project_name = "linux"
task = "BUG"
file = "{0}/{1}/{2}_dataset_{3}.csv"

df = pd.read_csv(file.format(directoryPath, project_name, project_name, task))
# df = utils.isRegularVersion(df)

# %%
# df[c.DATE] = pd.to_datetime(df[c.DATE])
# df[c.NT] = df[c.NT_CC] + df[c.NT_EC] + df[c.NT_UC]
# df[c.NO] = df[c.NO_CC] + df[c.NO_EC] + df[c.NO_UC]
# df[c.LINE] = df[c.LINE_CC] + df[c.LINE_EC] + df[c.LINE_UC]
# df[c.MODULE] = df[c.MODULE_CC] + df[c.MODULE_EC] + df[c.MODULE_UC]
# df[c.T_CONTRIBUTORS] = df[c.T_CC] + df[c.T_EC] + df[c.T_UC] + 2
df[c.NT] = df[[c.NT_CC]].sum(axis=1)
df[c.NO] = df[[c.NO_CC]].sum(axis=1)
df[c.LINE] = df[[c.LINE_CC]].sum(axis=1)
df[c.MODULE] = df[[c.MODULE_CC]].sum(axis=1)
df[c.T_CONTRIBUTORS] = df[[c.T_CC]].sum(axis=1)
df[c.T_LINE + "_P"] = df[c.T_LINE].shift()
df[c.T_MODULE + "_P"] = df[c.T_MODULE].shift()
# df.drop(df.columns[0], axis=1, inplace=True)
# df.drop(c.DATE, axis=1, inplace=True)
# df.drop(c.PROJECT, axis=1, inplace=True)
# df = utils.remove_outlier(df, c.LINE)
# df = utils.remove_outlier(df, c.MODULE)

if df.isna().values.any():
    df.fillna(0, inplace=True)

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                 Unnamed: 0  T_Module    T_Line     NT_CC     NO_CC  Module_CC  \
# Unnamed: 0        1.000000  0.989194  0.988527 -0.053986  0.104237  -0.106385
# T_Module          0.989194  1.000000  0.998673 -0.059405  0.110571  -0.111537
# NT              0.816831  1.000000  0.550904  0.400712  ...   0.365581
# NO              0.354032  0.435135  0.507136  0.962318  ...   0.861779
# Line            1.000000  0.816831  0.362520  0.336083  ...   0.337562
# Module          0.903068  0.937398  0.466232  0.407699  ...   0.393433
# T_Contributors  0.816831  1.000000  0.550904  0.400712  ...   0.365581
# T_Line_P       -0.088608 -0.067492 -0.103692  0.050759  ...   0.049578
# T_Module_P     -0.089419 -0.063956 -0.089529  0.054067  ...   0.048697
#
#                  Line_UC      T_UC        NT        NO      Line    Module  \
# Unnamed: 0      0.003506 -0.110215 -0.053986  0.104237 -0.081180 -0.106385
# T_Module        0.008502 -0.069634 -0.059405  0.110571 -0.084928 -0.111537
# T_Line          0.009829 -0.065767 -0.062179  0.106933 -0.083271 -0.110487
# NT_CC           0.449726 -0.028209  1.000000  0.435135  0.816831  0.937398
# NO_CC           0.830482 -0.039650  0.435135  1.000000  0.354032  0.431575
# Module_CC       0.476844 -0.023471  0.937398  0.431575  0.903068  1.000000
# Line_CC         0.407809 -0.022835  0.816831  0.354032  1.000000  0.903068
# T_CC            0.449726 -0.028209  1.000000  0.435135  0.816831  0.937398
# NT_EC           0.438899 -0.047419  0.550904  0.507136  0.362520  0.466232
# NO_EC           0.869111 -0.044395  0.400712  0.962318  0.336083  0.407699
# Module_EC       0.390051 -0.039217  0.404083  0.395753  0.270284  0.358968
# Line_EC         0.402248 -0.031426  0.293868  0.414040  0.221037  0.273639
# T_EC            0.438899 -0.047419  0.550904  0.507136  0.362520  0.466232
# NT_UC           0.939694 -0.061394  0.355853  0.882868  0.324375  0.381110
# NO_UC           0.903139 -0.045730  0.319460  0.890703  0.277497  0.335944
# Module_UC       0.952780 -0.056721  0.365581  0.861779  0.337562  0.393433
# Line_UC         1.000000 -0.049081  0.449726  0.830482  0.407809  0.476844
# T_UC           -0.049081  1.000000 -0.028209 -0.039650 -0.022835 -0.023471
# NT              0.449726 -0.028209  1.000000  0.435135  0.816831  0.937398
# NO              0.830482 -0.039650  0.435135  1.000000  0.354032  0.431575
# Line            0.407809 -0.022835  0.816831  0.354032  1.000000  0.903068
# Module          0.476844 -0.023471  0.937398  0.431575  0.903068  1.000000
# T_Contributors  0.449726 -0.028209  1.000000  0.435135  0.816831  0.937398
# T_Line_P       -0.002191 -0.123130 -0.067492  0.094760 -0.088608 -0.116426
# T_Module_P     -0.003005 -0.126992 -0.063956  0.098755 -0.089419 -0.116700
#
#                 T_Contributors  T_Line_P  T_Module_P
# Unnamed: 0           -0.053986  0.987865    0.988356
# T_Module             -0.059405  0.980714    0.982216
# T_Line               -0.062179  0.981534    0.980427
# NT_CC                 1.000000 -0.067492   -0.063956
# NO_CC                 0.435135  0.094760    0.098755
# Module_CC             0.937398 -0.116426   -0.116700
# Line_CC               0.816831 -0.088608   -0.089419
# T_CC                  1.000000 -0.067492   -0.063956
# NT_EC                 0.550904 -0.103692   -0.089529
# NO_EC                 0.400712  0.050759    0.054067
# Module_EC             0.404083 -0.159478   -0.150569
# Line_EC               0.293868 -0.157292   -0.150963
# T_EC                  0.550904 -0.103692   -0.089529
# NT_UC                 0.355853  0.098626    0.097587
# NO_UC                 0.319460  0.115652    0.116094
# Module_UC             0.365581  0.049578    0.048697
# Line_UC               0.449726 -0.002191   -0.003005
# T_UC                 -0.028209 -0.123130   -0.126992
# NT                    1.000000 -0.067492   -0.063956
# NO                    0.435135  0.094760    0.098755
# Line                  0.816831 -0.088608   -0.089419
# Module                0.937398 -0.116426   -0.116700
# T_Contributors        1.000000 -0.067492   -0.063956
# T_Line_P             -0.067492  1.000000    0.998680
# T_Module_P           -0.063956  0.998680    1.000000
#
# [25 rows x 25 columns]

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=c.NT, y=c.LINE, c='red')
df.plot.scatter(x=c.NO, y=c.LINE, c='green')

# %%
df[[c.LINE, c.MODULE]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcbd899bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcbd89b9d90>]],
#       dtype=object)

# %%
X = df[[c.NT, c.NO, c.T_CONTRIBUTORS]]
Y = df[c.LINE]

splits = 10
num_records = len(X)

if num_records <= splits:
    splits = num_records

pipeline = Pipeline(steps=[('scaler', transformer), ('predictor', regressor)])
model = TransformedTargetRegressor(regressor=pipeline, transformer=transformer)
model.fit(X, Y)

kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-237-67c7fb5b90be> in <module>
#       8     splits = num_records
#       9
# ---> 10 pipeline = Pipeline(steps=[('scaler', transformer), ('predictor', regressor)])
#      11 model = TransformedTargetRegressor(regressor=pipeline, transformer=transformer)
#      12 model.fit(X, Y)
#
# NameError: name 'transformer' is not defined

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results[c.PERCENT_ERROR].fillna(0, inplace=True)
results[c.PERCENT_ERROR].replace(np.inf, 0, inplace=True)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.75, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(1.00, results, c.PERCENT_ERROR), 2))
# print("Standard Deviation: {0}: ".format(results[c.DIFFERENCE].mean(axis = 0)) )
results.head(500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-238-42ec98ca94f0> in <module>
#       1 data = {}
#       2 data[c.OBSERVED] = Y.round(2)
# ----> 3 data[c.PREDICTED] = predictions.round(2)
#       4 data[c.DIFFERENCE] = abs(Y - predictions).round(2)
#       5 data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
#
# NameError: name 'predictions' is not defined

# %%
results[c.PERCENT_ERROR].hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-239-2a577400cdb5> in <module>
# ----> 1 results[c.PERCENT_ERROR].hist()
#
# NameError: name 'results' is not defined

# %%
feature_importances = pd.DataFrame(model.regressor_.named_steps['predictor'].feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-240-e63633ed1b81> in <module>
# ----> 1 feature_importances = pd.DataFrame(model.regressor_.named_steps['predictor'].feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
#       2 feature_importances
#
# NameError: name 'model' is not defined

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-241-9752bc9c93ec> in <module>
# ----> 1 ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
#       2 results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
#
# NameError: name 'results' is not defined

# %%
df.plot.scatter(x=c.NT, y=c.MODULE, c='red')
df.plot.scatter(x=c.NO, y=c.MODULE, c='green')

# %%
# Let's create multiple regression
X = df[[c.NT, c.NO, c.T_CONTRIBUTORS]]
Y = df[c.MODULE]

splits = 10
num_records = len(X)

pipeline = Pipeline(steps=[('scaler', transformer), ('predictor', regressor)])
model = TransformedTargetRegressor(regressor=pipeline, transformer=transformer)
model.fit(X, Y)
kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-386e8a3e4eb2> in <module>
#       6 num_records = len(X)
#       7
# ----> 8 pipeline = Pipeline(steps=[('scaler', transformer), ('predictor', regressor)])
#       9 model = TransformedTargetRegressor(regressor=pipeline, transformer=transformer)
#      10 model.fit(X, Y)
#
# NameError: name 'transformer' is not defined

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results[c.PERCENT_ERROR].fillna(0, inplace=True)
results[c.PERCENT_ERROR].replace(np.inf, 0, inplace=True)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.75, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(1.00, results, c.PERCENT_ERROR), 2))
results.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-244-5fd86956e0da> in <module>
#       1 data = {}
#       2 data[c.OBSERVED] = Y.round(2)
# ----> 3 data[c.PREDICTED] = predictions.round(2)
#       4 data[c.DIFFERENCE] = abs(Y - predictions).round(2)
#       5 data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
#
# NameError: name 'predictions' is not defined

# %%
results.boxplot(column=[c.PERCENT_ERROR])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-245-5a71727bcc89> in <module>
# ----> 1 results.boxplot(column=[c.PERCENT_ERROR])
#
# NameError: name 'results' is not defined

# %%
feature_importances = pd.DataFrame(model.regressor_.named_steps['predictor'].feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-246-e63633ed1b81> in <module>
# ----> 1 feature_importances = pd.DataFrame(model.regressor_.named_steps['predictor'].feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
#       2 feature_importances
#
# NameError: name 'model' is not defined

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-247-9752bc9c93ec> in <module>
# ----> 1 ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
#       2 results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
#
# NameError: name 'results' is not defined
