# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import os as os
sys.path.append('../../')
import Constants as c
import Utilities as utils
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import model_selection
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
# %matplotlib inline

# %%
def get_NT(df, task_type):
    nt = pd.read_csv(file.format(directoryPath, project_name, project_name, task_type))
    if nt.isna().values.any():
        nt.fillna(0, inplace=True)
    df[c.NT + "_" + task_type] = nt[c.NT_CC] + nt[c.NT_EC] + nt[c.NT_UC]

# %%
directoryPath = "../../exports"
project_name = "angular"
task = "BUG"
file = "{0}/{1}/{2}_dataset_{3}.csv"

df = pd.read_csv(file.format(directoryPath, project_name, project_name, task))

# df = utils.isRegularVersion(df)
get_NT(df, "DOCS")
get_NT(df, "REFACTOR")
get_NT(df, "TESTING")
get_NT(df, "FEATURE")
get_NT(df, "UPGRADE")
get_NT(df, "RELEASE")
get_NT(df, "SUPPORT")
get_NT(df, "OTHER")

df[c.DATE] = pd.to_datetime(df[c.DATE])
df['diff_hours'] = df[c.DATE].diff(-1) * (-1) / np.timedelta64(1, 'h')
df['diff_hours'] = utils.standardize(df, 'diff_hours')
df['year'] = df[c.DATE].dt.year
df['year'] = utils.standardize(df, 'year')
df['month'] = df[c.DATE].dt.month
df['month'] = utils.standardize(df, 'month')
df['day'] = df[c.DATE].dt.day
df['day'] = utils.standardize(df, 'day')
df['quarter'] = df[c.DATE].dt.quarter
df['quarter'] = utils.standardize(df, 'quarter')
df[c.NT] = df[c.NT_CC] + df[c.NT_EC] + df[c.NT_UC]
df[c.NO] = df[c.NO_CC] + df[c.NO_EC] + df[c.NO_UC]
df[c.LINE] = df[c.LINE_CC] + df[c.LINE_EC] + df[c.LINE_UC]
df[c.MODULE] = df[c.MODULE_CC] + df[c.MODULE_EC] + df[c.MODULE_UC]
df[c.T_CONTRIBUTORS] = df[c.T_CC] + df[c.T_EC] + df[c.T_UC] + 2
df.drop(df.columns[0], axis=1, inplace=True)
df.drop(c.DATE, axis=1, inplace=True)
df.drop(c.PROJECT, axis=1, inplace=True)
# df.drop(c.VERSION, axis=1, inplace=True)
# df.drop("f0_", axis=1, inplace=True)

if df.isna().values.any():
    df.fillna(0, inplace=True)

#Capping the outlier rows with Percentiles
# upper_lim = df[c.MODULE].quantile(.95)
# lower_lim = df[c.MODULE].quantile(.05)
# df.loc[(df[c.MODULE] > upper_lim),c.MODULE] = upper_lim
# df.loc[(df[c.MODULE] < lower_lim),c.MODULE] = lower_lim

# upper_lim = df[c.LINE].quantile(.95)
# lower_lim = df[c.LINE].quantile(.05)
# df.loc[(df[c.LINE] > upper_lim),c.LINE] = upper_lim
# df.loc[(df[c.LINE] < lower_lim),c.LINE] = lower_lim

percent_25 = df[c.MODULE].quantile(.25)
percent_50 = df[c.MODULE].quantile(.50)
percent_75 = df[c.MODULE].quantile(.75)

# df['Module_Bin'] = pd.cut(df[c.MODULE], bins=[df[c.MODULE].min(),percent_25,percent_50,percent_75, df[c.MODULE].max()], labels=[0,1,2], duplicates='drop')
# df.head()

# percent_25 = df[c.LINE].quantile(.25)
# percent_50 = df[c.LINE].quantile(.50)
# percent_75 = df[c.LINE].quantile(.75)

# df['Line_Bin'] = pd.cut(df[c.LINE], bins=[df[c.LINE].min(),percent_25,percent_50,percent_75, df[c.LINE].max()], labels=[0,1,2,3], duplicates='drop')

conditions = [
    df[c.VERSION].str.contains('-rc'),
    df[c.VERSION].str.contains('-beta'),
    df[c.VERSION].str.contains('-alpha')
]

choices = [2, 3, 4]

df['Release'] = np.select(conditions, choices, default=1)

if df.isna().values.any():
    df.fillna(0, inplace=True)

# %%
df[c.T_MODULE] = utils.standardize(df, c.T_MODULE)
df[c.T_LINE] = utils.standardize(df, c.LINE)

# %%
# print out a correlation matrix of our data frame
corr = df.corr()

# display it
display(corr)
# Out:
#                 T_Module    T_Line     NT_CC     NO_CC  Module_CC   Line_CC  \
# T_Module        1.000000  0.044879  0.068183  0.131407   0.083492  0.122168
# T_Line          0.044879  1.000000  0.752724  0.791543   0.692070  0.796744
# NT_CC           0.068183  0.752724  1.000000  0.918269   0.807560  0.889880
# NO_CC           0.131407  0.791543  0.918269  1.000000   0.703686  0.841917
# Module_CC       0.083492  0.692070  0.807560  0.703686   1.000000  0.933145
# Line_CC         0.122168  0.796744  0.889880  0.841917   0.933145  1.000000
# T_CC            0.068183  0.752724  1.000000  0.918269   0.807560  0.889880
# NT_EC          -0.174460  0.661722  0.360484  0.282899   0.286970  0.303832
# NO_EC           0.055521  0.908107  0.784640  0.901106   0.603517  0.748411
# Module_EC      -0.106673  0.510574  0.122628  0.098589   0.087825  0.095252
# Line_EC        -0.057047  0.448218  0.123424  0.118195   0.082160  0.110778
# T_EC           -0.174460  0.661722  0.360484  0.282899   0.286970  0.303832
# NT_UC           0.363624  0.299984  0.140647  0.310062   0.086161  0.196775
# NO_UC           0.385936  0.285610  0.122727  0.301555   0.074192  0.180966
# Module_UC       0.327270  0.223747  0.079352  0.226553   0.044283  0.129630
# Line_UC         0.339934  0.289550  0.146254  0.299230   0.074212  0.178100
# T_UC           -0.138986 -0.230310 -0.207146 -0.179395  -0.182327 -0.189411
# NT_DOCS         0.350195  0.610307  0.732501  0.858617   0.510893  0.646641
# NT_REFACTOR     0.093498  0.756208  0.604065  0.679520   0.446597  0.572554
# NT_TESTING      0.292910  0.754552  0.673756  0.785526   0.500417  0.662232
# NT_FEATURE     -0.020508  0.821933  0.618510  0.609206   0.523768  0.572101
# NT_UPGRADE      0.024048  0.394583  0.582277  0.489058   0.545677  0.529952
# NT_RELEASE      0.253795  0.570788  0.825525  0.811170   0.653217  0.704668
# NT_SUPPORT      0.289412  0.461028  0.597330  0.630593   0.443477  0.533603
# NT_OTHER        0.205801  0.699857  0.746902  0.779267   0.589857  0.666386
# diff_hours     -0.186983  0.213233  0.005007  0.023991   0.026869  0.059973
# year            0.948919  0.078108  0.091346  0.143897   0.086948  0.121614
# month          -0.074857 -0.170759 -0.140654 -0.130360  -0.213096 -0.166431
# day             0.052327 -0.003909 -0.027573 -0.034492   0.037857  0.023613
# quarter        -0.060987 -0.165318 -0.137259 -0.123892  -0.208109 -0.157448
# NT             -0.029840  0.939931  0.763729  0.765059   0.623966  0.721804
# NO              0.096120  0.870573  0.786786  0.929205   0.605788  0.767284
# Line            0.044879  1.000000  0.752724  0.791543   0.692070  0.796744
# Module         -0.013702  0.938862  0.652190  0.640634   0.687942  0.701826
# T_Contributors -0.058220  0.890084  0.737568  0.673202   0.620427  0.681069
# Release        -0.484677  0.121777  0.021291  0.051823   0.028968  0.073132
#
#                     T_CC     NT_EC     NO_EC  Module_EC  ...      year  \
# T_Module        0.068183 -0.174460  0.055521  -0.106673  ...  0.948919
# T_Line          0.752724  0.661722  0.908107   0.510574  ...  0.078108
# NT_CC           1.000000  0.360484  0.784640   0.122628  ...  0.091346
# NO_CC           0.918269  0.282899  0.901106   0.098589  ...  0.143897
# Module_CC       0.807560  0.286970  0.603517   0.087825  ...  0.086948
# Line_CC         0.889880  0.303832  0.748411   0.095252  ...  0.121614
# T_CC            1.000000  0.360484  0.784640   0.122628  ...  0.091346
# NT_EC           0.360484  1.000000  0.521671   0.824404  ... -0.130406
# NO_EC           0.784640  0.521671  1.000000   0.342899  ...  0.097814
# Module_EC       0.122628  0.824404  0.342899   1.000000  ... -0.086076
# Line_EC         0.123424  0.680184  0.329649   0.914404  ... -0.044005
# T_EC            0.360484  1.000000  0.521671   0.824404  ... -0.130406
# NT_UC           0.140647  0.017791  0.361983  -0.008588  ...  0.397055
# NO_UC           0.122727 -0.006673  0.352677  -0.016698  ...  0.408765
# Module_UC       0.079352  0.006479  0.273862  -0.005448  ...  0.360047
# Line_UC         0.146254  0.039473  0.352964   0.001412  ...  0.388818
# T_UC           -0.207146 -0.118436 -0.187873  -0.038614  ... -0.193315
# NT_DOCS         0.732501  0.130169  0.767761   0.029697  ...  0.367850
# NT_REFACTOR     0.604065  0.566171  0.797449   0.326964  ...  0.152715
# NT_TESTING      0.673756  0.287521  0.803003   0.223955  ...  0.338668
# NT_FEATURE      0.618510  0.760857  0.746486   0.637975  ... -0.015245
# NT_UPGRADE      0.582277  0.163738  0.379144   0.035535  ... -0.003083
# NT_RELEASE      0.825525  0.205247  0.656886   0.024812  ...  0.263408
# NT_SUPPORT      0.597330  0.174365  0.521421   0.029924  ...  0.234551
# NT_OTHER        0.746902  0.392054  0.764722   0.183944  ...  0.229818
# diff_hours      0.005007  0.264155  0.117679   0.285421  ... -0.212972
# year            0.091346 -0.130406  0.097814  -0.086076  ...  1.000000
# month          -0.140654 -0.026582 -0.147830   0.020982  ... -0.276273
# day            -0.027573 -0.000206 -0.036222   0.011410  ...  0.044712
# quarter        -0.137259 -0.033440 -0.139223   0.016416  ... -0.255241
# NT              0.763729  0.785470  0.893194   0.533043  ...  0.017467
# NO              0.786786  0.376847  0.968712   0.192896  ...  0.131737
# Line            0.752724  0.661722  0.908107   0.510574  ...  0.078108
# Module          0.652190  0.766374  0.784018   0.666996  ...  0.015208
# T_Contributors  0.737568  0.845706  0.804393   0.584996  ... -0.013987
# Release         0.021291  0.081785  0.089485   0.009911  ... -0.549667
#
#                    month       day   quarter        NT        NO      Line  \
# T_Module       -0.074857  0.052327 -0.060987 -0.029840  0.096120  0.044879
# T_Line         -0.170759 -0.003909 -0.165318  0.939931  0.870573  1.000000
# NT_CC          -0.140654 -0.027573 -0.137259  0.763729  0.786786  0.752724
# NO_CC          -0.130360 -0.034492 -0.123892  0.765059  0.929205  0.791543
# Module_CC      -0.213096  0.037857 -0.208109  0.623966  0.605788  0.692070
# Line_CC        -0.166431  0.023613 -0.157448  0.721804  0.767284  0.796744
# T_CC           -0.140654 -0.027573 -0.137259  0.763729  0.786786  0.752724
# NT_EC          -0.026582 -0.000206 -0.033440  0.785470  0.376847  0.661722
# NO_EC          -0.147830 -0.036222 -0.139223  0.893194  0.968712  0.908107
# Module_EC       0.020982  0.011410  0.016416  0.533043  0.192896  0.510574
# Line_EC         0.025933  0.006984  0.027065  0.448743  0.189377  0.448218
# T_EC           -0.026582 -0.000206 -0.033440  0.785470  0.376847  0.661722
# NT_UC          -0.148854  0.000091 -0.153206  0.247529  0.415398  0.299984
# NO_UC          -0.113450  0.001096 -0.112298  0.226225  0.408725  0.285610
# Module_UC      -0.173220  0.005222 -0.183237  0.181248  0.318585  0.223747
# Line_UC        -0.201241 -0.012571 -0.208035  0.251096  0.398551  0.289550
# T_UC            0.165799  0.027704  0.153615 -0.247510 -0.227347 -0.230310
# NT_DOCS        -0.104355 -0.030277 -0.097089  0.574176  0.793611  0.610307
# NT_REFACTOR    -0.128784  0.004304 -0.132233  0.789394  0.761624  0.756208
# NT_TESTING     -0.212741 -0.018737 -0.219006  0.678948  0.822465  0.754552
# NT_FEATURE     -0.050871 -0.012159 -0.055542  0.834603  0.658864  0.821933
# NT_UPGRADE     -0.016644  0.020095 -0.020958  0.377480  0.376705  0.394583
# NT_RELEASE     -0.049671 -0.000986 -0.045213  0.588437  0.678952  0.570788
# NT_SUPPORT      0.080821 -0.027856  0.066322  0.460247  0.520060  0.461028
# NT_OTHER       -0.154074 -0.027422 -0.156948  0.715252  0.757106  0.699857
# diff_hours      0.018911 -0.022509  0.002643  0.205082  0.095640  0.213233
# year           -0.276273  0.044712 -0.255241  0.017467  0.131737  0.078108
# month           1.000000 -0.056018  0.971947 -0.141129 -0.167261 -0.170759
# day            -0.056018  1.000000 -0.034639 -0.019627 -0.037833 -0.003909
# quarter         0.971947 -0.034639  1.000000 -0.138860 -0.156745 -0.165318
# NT             -0.141129 -0.019627 -0.138860  1.000000  0.842208  0.939931
# NO             -0.167261 -0.037833 -0.156745  0.842208  1.000000  0.870573
# Line           -0.170759 -0.003909 -0.165318  0.939931  0.870573  1.000000
# Module         -0.148669  0.015064 -0.148773  0.898034  0.711279  0.938862
# T_Contributors -0.120635 -0.008786 -0.120230  0.977529  0.730878  0.890084
# Release        -0.003233  0.005232 -0.009235  0.111311  0.101105  0.121777
#
#                   Module  T_Contributors   Release
# T_Module       -0.013702       -0.058220 -0.484677
# T_Line          0.938862        0.890084  0.121777
# NT_CC           0.652190        0.737568  0.021291
# NO_CC           0.640634        0.673202  0.051823
# Module_CC       0.687942        0.620427  0.028968
# Line_CC         0.701826        0.681069  0.073132
# T_CC            0.652190        0.737568  0.021291
# NT_EC           0.766374        0.845706  0.081785
# NO_EC           0.784018        0.804393  0.089485
# Module_EC       0.666996        0.584996  0.009911
# Line_EC         0.540977        0.482151 -0.001726
# T_EC            0.766374        0.845706  0.081785
# NT_UC           0.191161        0.137715 -0.135345
# NO_UC           0.179012        0.115612 -0.148852
# Module_UC       0.142284        0.090133 -0.125930
# Line_UC         0.181288        0.151015 -0.132341
# T_UC           -0.207957       -0.245828 -0.076570
# NT_DOCS         0.460108        0.484730 -0.129112
# NT_REFACTOR     0.658738        0.722666  0.049977
# NT_TESTING      0.617692        0.579190 -0.010019
# NT_FEATURE      0.847461        0.837041  0.121070
# NT_UPGRADE      0.376170        0.387752 -0.061924
# NT_RELEASE      0.500200        0.552490 -0.175948
# NT_SUPPORT      0.373157        0.424335 -0.051010
# NT_OTHER        0.609773        0.660059 -0.071996
# diff_hours      0.270955        0.213895  0.391998
# year            0.015208       -0.013987 -0.549667
# month          -0.148669       -0.120635 -0.003233
# day             0.015064       -0.008786  0.005232
# quarter        -0.148773       -0.120230 -0.009235
# NT              0.898034        0.977529  0.111311
# NO              0.711279        0.730878  0.101105
# Line            0.938862        0.890084  0.121777
# Module          1.000000        0.893567  0.092141
# T_Contributors  0.893567        1.000000  0.103461
# Release         0.092141        0.103461  1.000000
#
# [36 rows x 36 columns]

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')

# %%
df.plot.scatter(x=c.NT, y=c.LINE, c='red')
df.plot.scatter(x=c.NO, y=c.LINE, c='green')

# %%
# X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS, 'Line_Bin', 'quarter', 'Release', 'diff_hours', 'year', 'month', 'day']]
# X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS, 'diff_hours',  'month', 'Release',
# "NT_DOCS", "NT_REFACTOR", "NT_TESTING", "NT_FEATURE", "NT_UPGRADE", "NT_RELEASE", "NT_SUPPORT","NT_OTHER" ]]
X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS ]]
# X = df[[c.NT, c.NO, 'Line_Bin', c.T_CONTRIBUTORS ]]
Y = df[c.LINE]

splits = 10
num_records = len(X)

if num_records <= splits:
    splits = num_records

model = DecisionTreeRegressor(random_state=0)
# model = RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=0)
model.fit(X, Y)

kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)
# Interpreting Restuls:  https://www.youtube.com/watch?v=U7D1h5bbpcs

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
# results
# Out:
# 0.91
# 0.98

# %%
feature_importances = pd.DataFrame(model.feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                 importance
# T_Line            0.851670
# NT                0.145942
# T_Module          0.002085
# NO                0.000182
# T_Contributors    0.000121

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)

# %%
df.plot.scatter(x=c.NT, y=c.MODULE, c='red')
df.plot.scatter(x=c.NO, y=c.MODULE, c='green')

# %%
# Let's create multiple regression
# X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS, 'diff_hours',  'month', 'Release',
# "NT_DOCS", "NT_REFACTOR", "NT_TESTING", "NT_FEATURE", "NT_UPGRADE", "NT_RELEASE", "NT_SUPPORT","NT_OTHER" ]]
X = df[[c.NT, c.NO, c.T_MODULE, c.T_LINE, c.T_CONTRIBUTORS ]]
# X = df[[c.NT, c.NO,'Module_Bin', c.T_CONTRIBUTORS, c.T_MODULE  ]]
Y = df[c.MODULE]

splits = 10
num_records = len(X)


model = DecisionTreeRegressor(random_state=0)
# model = RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=0)
model.fit(X, Y)

kfold = model_selection.KFold(n_splits=splits)
predictions = cross_val_predict(model, X, Y, cv=kfold)

# %%
data = {}
data[c.OBSERVED] = Y.round(2)
data[c.PREDICTED] = predictions.round(2)
data[c.DIFFERENCE] = abs(Y - predictions).round(2)
data[c.PERCENT_ERROR] = (abs(Y - predictions)/Y).round(2)
results = pd.DataFrame(data)
results['Version'] = np.arange(results.__len__())
print(round(utils.calculate_PRED(0.25, results, c.PERCENT_ERROR), 2))
print(round(utils.calculate_PRED(0.50, results, c.PERCENT_ERROR), 2))
# Out:
# 0.54
# 0.77

# %%
feature_importances = pd.DataFrame(model.feature_importances_, index = X.columns,columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                 importance
# T_Line            0.893257
# T_Module          0.044216
# T_Contributors    0.033098
# NO                0.017727
# NT                0.011702

# %%
ax = results.plot(kind='scatter', x='Version', y='Observed', c='green', label='Observed')
results.plot(kind='scatter', x='Version', y='Predicted', c='blue', label='Predicted', ax=ax)
