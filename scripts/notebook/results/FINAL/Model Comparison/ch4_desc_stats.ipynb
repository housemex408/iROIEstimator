# %%
import numpy as np
import pandas as pd
import os
import sys
import seaborn as sb
import matplotlib.pyplot as plt 
sys.path.append(os.path.abspath("../../../../"))
import Constants as c
import Utilities as utils
# %matplotlib inline

# %%
results = "h2_metrics_h1_DT_05_29_2020.csv"
columns = [c.MODEL, c.R_SQUARED, c.MAE, c.PRED_25, c.PRED_50, c.T_RECORDS, c.T_RECORDS, "P_NA"]
df = pd.read_csv(results, usecols=columns)
pd.options.display.float_format = "{:.2f}".format
df = utils.remove_outlier(df, c.MAE)
fig = plt.figure(figsize=(10,5))
plt.tight_layout()
sb.set(style="dark", palette="pastel")
ax = sb.boxplot(x=c.MODEL, y=c.MAE, data=df)

# %%
df.describe()
# Out:
#        R_Squared     MAE  PRED_25  PRED_50  T_Records    P_NA
# count    2829.00 2829.00  2829.00  2829.00    2829.00 2829.00
# mean        0.68   25.10     0.87     0.90     262.41    0.61
# std         0.34   49.59     0.15     0.11     241.30    0.16
# min        -0.14    0.00     0.16     0.32      22.00    0.01
# 25%         0.44    0.12     0.81     0.85     135.00    0.54
# 50%         0.81    2.44     0.93     0.94     192.00    0.67
# 75%         0.99   21.25     0.99     0.99     303.00    0.73
# max         1.00  254.86     1.00     1.00    1504.00    0.76

# %%
results = "h2_metrics_h1_LR_05_29_2020.csv"
df = pd.read_csv(results, usecols=columns)
df = utils.remove_outlier(df, c.MAE)

# %%
fig = plt.figure(figsize=(10,5))
plt.tight_layout()
sb.set(style="dark", palette="pastel")
ax = sb.boxplot(x=c.MODEL, y=c.MAE, data=df)

# %%
df.describe()
# Out:
#        R_Squared     MAE  PRED_25  PRED_50  T_Records    P_NA
# count    2835.00 2835.00  2835.00  2835.00    2835.00 2835.00
# mean        0.50   26.63     0.87     0.90     261.63    0.61
# std         0.68   52.59     0.15     0.11     240.29    0.16
# min        -8.32    0.00     0.14     0.35      22.00    0.01
# 25%         0.19    0.11     0.80     0.84     135.00    0.54
# 50%         0.71    2.47     0.93     0.94     192.00    0.67
# 75%         1.00   21.61     0.99     0.99     284.00    0.73
# max         1.00  269.44     1.00     1.00    1504.00    0.76
